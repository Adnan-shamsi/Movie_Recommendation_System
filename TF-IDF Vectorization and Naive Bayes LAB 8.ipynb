# %% [markdown]
# # Part A) Naive Bayes tf-idf language Model

# %%
import csv
import random
import re
import nltk
from collections import defaultdict
import math

# %% [markdown]
# # Reading file

# %%
def readCSV(fileName):
   
    rows  =  []
    result = []
    
    with open(fileName, 'r',encoding="utf8") as csvfile:

        # creating a csv reader object
        csvreader = csv.reader(csvfile)

        # extracting each data row one by one
        for row in csvreader:
            #print(row)
            rows.append(row)
    return rows

# %% [markdown]
# # Splitting testing and training data

# %%
def splitTrainAndTestData(rows, percent = 0.7,seed = 40):    
    random.seed(seed)
    rows.sort()
    trainSize = int(len(rows) * percent)
    random.shuffle(rows)
    return rows[:trainSize] , rows[trainSize:]

# %%
def preprocess(rows):
    for row in rows:
        row[0] = row[0].lower()

# %% [markdown]
# # starting function execution

# %%
rows = readCSV(r"./CSV_FOLDER/message.csv")

# %%
preprocess(rows)

# %%
rows
# Out:
# [['i love this sandwich', 'pos'],
#  ['this is an amazing place', 'pos'],
#  ['i feel very good about these beers', 'pos'],
#  ['this is my best work', 'pos'],
#  ['what an awesome view', 'pos'],
#  ['i do not like this restaurant', 'neg'],
#  ['i am tired of this stuff', 'neg'],
#  ['i can not deal with this', 'neg'],
#  ['he is my sworn enemy', 'neg'],
#  ['my boss is horrible', 'neg'],
#  ['this is an awesome place', 'pos'],
#  ['i do not like the taste of this juice', 'neg'],
#  ['i love to dance', 'pos'],
#  ['i am sick and tired of this place', 'neg'],
#  ['what a great holiday', 'pos'],
#  ['that is a bad locality to stay', 'neg'],
#  ['we will have good fun tomorrow', 'pos'],
#  ['i went to my enemy house today', 'neg']]

# %%
class NaiveBayes_tf_idf:
    
    def __init__(self, x_train, y_train):
        self.x_train = []
        self.y_train = y_train
        self.total_doc = len(y_train)
        print(self.total_doc)
        self.trainOnce = False
        for idx in range(len(x_train)):
            self.x_train.append(x_train[idx].split())
    
    def calculate_tf_idf(self):
        self.tf = [] 
        self.idf = defaultdict(int);
        distinct_words = set(); 
        word_in_distinct_doc = defaultdict(int)
        
        for idx in range(self.total_doc):
            self.tf.append(defaultdict(int))
            for word in self.x_train[idx]:
                distinct_words.add(word)

        # Now calculating tf
        for word in distinct_words:
            for idx in range(self.total_doc):
                self.tf[idx][word] = self.x_train[idx].count(word)/len(self.x_train[idx]);
        
        # Now calculating idf
        for word in distinct_words:
            for idx in range(self.total_doc):
                if self.x_train[idx].count(word):
                        word_in_distinct_doc[word] += 1;
        
        for word in distinct_words:
            self.idf[word] = math.log((1 + len(self.x_train))/(1 + word_in_distinct_doc[word]) + 1,10)
        #print(self.tf)
    
    
    def calculate_weight(self):
        self.weight = [] 
        for idx in range(len(self.tf)):
            self.weight.append(defaultdict(int));
            for word in self.tf[idx]:
                self.weight[idx][word] = self.tf[idx][word] * self.idf[word]
    
    def trainModel(self):
        if self.trainOnce == True:
            return
        self.trainOnce = True 

        self.calculate_tf_idf()
        self.calculate_weight()
        
        self.trainCount = defaultdict(lambda: defaultdict(int));
        self.totalWordsinClass = defaultdict(int);
        self.classCount = defaultdict(int)
        
        for idx in range(self.total_doc):
            self.classCount[self.y_train[idx]] += 1
            for word in self.x_train[idx]:
                self.trainCount[y_train[idx]][word]  += self.weight[idx][word]
                self.totalWordsinClass[y_train[idx]] += self.weight[idx][word]
    
    
    def testModel(self, sentence, tell_all_word_prob = False):
        def myPrint(*args):
            if tell_all_word_prob:
                print(" ".join(args))
            
        all_prob = []
        #return sentence
        myPrint(f'->Test Sentence is:\n',sentence,'\n')
        sentence = sentence.split()
        myPrint(f'tokens\n{sentence}')
        
        #print(sentence)
        #return self.classCount
        
        for key in self.classCount:
            myPrint(f"for class {key}")
            #print("hi")
            prob = 1.0
            for token in sentence:
                if token not in self.trainCount[key].keys():
                    num = 0
                else:
                    num = self.trainCount[key][token];
                    #print('found')
                denum = self.totalWordsinClass[key]
                num += 1                              # add one smooting
                denum += len(self.trainCount[key])    #add one smooting
                prob *= num / denum
                myPrint("\t",f"the probability of word ({token}) is {num / denum}")
            prob *= self.classCount[key] / self.total_doc
            #print(prob)
            
            all_prob.append((prob, key))
        all_prob.sort(reverse=True)
        total = 0
        for x in all_prob:
            total += x[0];
        #print(total)    
        return (round(all_prob[0][0]/total*100,2),all_prob[0][1])

# %%
training, testing = splitTrainAndTestData(rows)

# %%
x_train, y_train = [t[0] for t in rows] , [t[1] for t in rows]

# %%
x_test, y_test = [t[0] for t in testing] , [t[1] for t in testing]

# %%
model = NaiveBayes_tf_idf(x_train, y_train)
# Out:
# 18

# %%
model.trainModel()

# %% [markdown]
# # Testing data

# %%
x_test[0]
model.testModel(x_test[0],True)
# Out:
# ->Test Sentence is:
#  my boss is horrible
#
# tokens
# ['my', 'boss', 'is', 'horrible']
# for class pos
# 	 the probability of word (my) is 0.030409840793833933
# 	 the probability of word (boss) is 0.026763377511391826
# 	 the probability of word (is) is 0.0359144503121491
# 	 the probability of word (horrible) is 0.026763377511391826
# for class neg
# 	 the probability of word (my) is 0.03323822630313742
# 	 the probability of word (boss) is 0.02972041356573502
# 	 the probability of word (is) is 0.031675040335868924
# 	 the probability of word (horrible) is 0.02972041356573502
# (54.31, 'neg')

# %%
countCorrect = 0
for t in testing:
    to_string = t[0]
    print('*'*10,to_string,'*'*10,'\n')
    x = model.testModel(to_string)
    if t[1] == x[1]:
        countCorrect += 1
        print(f"it's a {x[1].upper()} with {x[0]}% surety 😁 ")
    else:
        print(f"my code says it is {x[1].upper()} with {x[0]}% surety but it is not 😨")
    print('-' * 100)
# Out:
# ********** my boss is horrible **********
#
# it's a NEG with 54.31% surety 😁
# ----------------------------------------------------------------------------------------------------
# ********** i do not like the taste of this juice **********
#
# it's a NEG with 56.22% surety 😁
# ----------------------------------------------------------------------------------------------------
# ********** i can not deal with this **********
#
# it's a NEG with 51.73% surety 😁
# ----------------------------------------------------------------------------------------------------
# ********** i am sick and tired of this place **********
#
# my code says it is POS with 53.88% surety but it is not 😨
# ----------------------------------------------------------------------------------------------------
# ********** what a great holiday **********
#
# it's a POS with 79.96% surety 😁
# ----------------------------------------------------------------------------------------------------
# ********** this is my best work **********
#
# it's a POS with 69.31% surety 😁
# ----------------------------------------------------------------------------------------------------

# %%
model.tf
# Out:
# [defaultdict(int,
#              {'will': 0.16666666666666666,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.16666666666666666,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.16666666666666666,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.16666666666666666,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.16666666666666666,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.16666666666666666,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.2,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.2,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.2,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.2,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.2,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.14285714285714285,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.14285714285714285,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.14285714285714285,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.14285714285714285,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.14285714285714285,
#               'these': 0.14285714285714285,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.14285714285714285,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.2,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.2,
#               'horrible': 0.0,
#               'sworn': 0.2,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.2,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.2,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.14285714285714285,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.14285714285714285,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.14285714285714285,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.14285714285714285,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.14285714285714285,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.14285714285714285,
#               'love': 0.0,
#               'went': 0.14285714285714285}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.25,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.25,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.25,
#               'love': 0.25,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.25,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.25,
#               'i': 0.25,
#               'love': 0.25,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.16666666666666666,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.16666666666666666,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.16666666666666666,
#               'restaurant': 0.16666666666666666,
#               'amazing': 0.0,
#               'this': 0.16666666666666666,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.16666666666666666,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.16666666666666666,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.16666666666666666,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.16666666666666666,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.16666666666666666,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.16666666666666666,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.16666666666666666,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.25,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.25,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.25,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.25,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.14285714285714285,
#               'stay': 0.14285714285714285,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.14285714285714285,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.14285714285714285,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.14285714285714285,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.14285714285714285,
#               'like': 0.0,
#               'that': 0.14285714285714285,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.2,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.2,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.2,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.2,
#               'this': 0.2,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.25,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.25,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.25,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.25,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.1111111111111111,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.1111111111111111,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.1111111111111111,
#               'taste': 0.1111111111111111,
#               'of': 0.1111111111111111,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.1111111111111111,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.1111111111111111,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.1111111111111111,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.1111111111111111,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.16666666666666666,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.16666666666666666,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.16666666666666666,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.16666666666666666,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.16666666666666666,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.16666666666666666,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.125,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.125,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.125,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.125,
#               'best': 0.0,
#               'place': 0.125,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.125,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.125,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.125,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.25,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.25,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.25,
#               'holiday': 0.25,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.0,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.0,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.0,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.0,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.0,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0}),
#  defaultdict(int,
#              {'will': 0.0,
#               'house': 0.0,
#               'am': 0.0,
#               'bad': 0.0,
#               'stay': 0.0,
#               'the': 0.0,
#               'tomorrow': 0.0,
#               'very': 0.0,
#               'tired': 0.0,
#               'enemy': 0.0,
#               'what': 0.0,
#               'have': 0.0,
#               'sick': 0.0,
#               'great': 0.0,
#               'today': 0.0,
#               'an': 0.0,
#               'beers': 0.0,
#               'locality': 0.0,
#               'awesome': 0.0,
#               'he': 0.0,
#               'horrible': 0.0,
#               'sworn': 0.0,
#               'a': 0.0,
#               'holiday': 0.0,
#               'sandwich': 0.0,
#               'and': 0.0,
#               'best': 0.2,
#               'place': 0.0,
#               'do': 0.0,
#               'good': 0.0,
#               'my': 0.2,
#               'with': 0.0,
#               'juice': 0.0,
#               'taste': 0.0,
#               'of': 0.0,
#               'deal': 0.0,
#               'boss': 0.0,
#               'feel': 0.0,
#               'view': 0.0,
#               'can': 0.0,
#               'is': 0.2,
#               'about': 0.0,
#               'these': 0.0,
#               'to': 0.0,
#               'like': 0.0,
#               'that': 0.0,
#               'we': 0.0,
#               'work': 0.2,
#               'stuff': 0.0,
#               'not': 0.0,
#               'restaurant': 0.0,
#               'amazing': 0.0,
#               'this': 0.2,
#               'fun': 0.0,
#               'dance': 0.0,
#               'i': 0.0,
#               'love': 0.0,
#               'went': 0.0})]

# %%
model.idf
# Out:
# defaultdict(int,
#             {'will': 1.021189299069938,
#              'house': 1.021189299069938,
#              'am': 0.8653014261025437,
#              'bad': 1.021189299069938,
#              'stay': 1.021189299069938,
#              'the': 1.021189299069938,
#              'tomorrow': 1.021189299069938,
#              'very': 1.021189299069938,
#              'tired': 0.8653014261025437,
#              'enemy': 0.8653014261025437,
#              'what': 0.8653014261025437,
#              'have': 1.021189299069938,
#              'sick': 1.021189299069938,
#              'great': 1.021189299069938,
#              'today': 1.021189299069938,
#              'an': 0.7596678446896304,
#              'beers': 1.021189299069938,
#              'locality': 1.021189299069938,
#              'awesome': 0.8653014261025437,
#              'he': 1.021189299069938,
#              'horrible': 1.021189299069938,
#              'sworn': 1.021189299069938,
#              'a': 0.8653014261025437,
#              'holiday': 1.021189299069938,
#              'sandwich': 1.021189299069938,
#              'and': 1.021189299069938,
#              'best': 1.021189299069938,
#              'place': 0.7596678446896304,
#              'do': 0.8653014261025437,
#              'good': 0.8653014261025437,
#              'my': 0.6812412373755872,
#              'with': 1.021189299069938,
#              'juice': 1.021189299069938,
#              'taste': 1.021189299069938,
#              'of': 0.7596678446896304,
#              'deal': 1.021189299069938,
#              'boss': 1.021189299069938,
#              'feel': 1.021189299069938,
#              'view': 1.021189299069938,
#              'can': 1.021189299069938,
#              'is': 0.569875307956561,
#              'about': 1.021189299069938,
#              'these': 1.021189299069938,
#              'to': 0.7596678446896304,
#              'like': 0.8653014261025437,
#              'that': 1.021189299069938,
#              'we': 1.021189299069938,
#              'work': 1.021189299069938,
#              'stuff': 1.021189299069938,
#              'not': 0.7596678446896304,
#              'restaurant': 1.021189299069938,
#              'amazing': 1.021189299069938,
#              'this': 0.462397997898956,
#              'fun': 1.021189299069938,
#              'dance': 1.021189299069938,
#              'i': 0.462397997898956,
#              'love': 0.8653014261025437,
#              'went': 1.021189299069938})

# %% [markdown]
# # Using sklearn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
data = pd.DataFrame(data = rows,columns=['text','label'])

# %%
data['labelnum'] = data.label.map({'pos':1,'neg':0})

# %%
data
# Out:
#                                      text label  labelnum
# 0          we will have good fun tomorrow   pos         1
# 1                this is an awesome place   pos         1
# 2      i feel very good about these beers   pos         1
# 3                    he is my sworn enemy   neg         0
# 4          i went to my enemy house today   neg         0
# 5                    i love this sandwich   pos         1
# 6                         i love to dance   pos         1
# 7           i do not like this restaurant   neg         0
# 8                i am tired of this stuff   neg         0
# 9                    what an awesome view   pos         1
# 10         that is a bad locality to stay   neg         0
# 11               this is an amazing place   pos         1
# 12                    my boss is horrible   neg         0
# 13  i do not like the taste of this juice   neg         0
# 14               i can not deal with this   neg         0
# 15      i am sick and tired of this place   neg         0
# 16                   what a great holiday   pos         1
# 17                   this is my best work   pos         1

# %%
vectorizer = TfidfVectorizer()
transformation = vectorizer.fit_transform(data.text)

# %%
transformation
# Out:
# <18x56 sparse matrix of type '<class 'numpy.float64'>'
# 	with 91 stored elements in Compressed Sparse Row format>

# %%
pd.DataFrame(data=transformation.toarray(), columns=vectorizer.get_feature_names())
# Out:
#        about        am  amazing        an       and   awesome       bad  \
# 0   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.00000  0.484512  0.000000  0.538998  0.000000
# 2   0.416445  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.474251  0.00000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.00000  0.443222  0.000000  0.493066  0.000000
# 10  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.447352
# 11  0.000000  0.000000  0.59018  0.464359  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.390451  0.00000  0.000000  0.446081  0.000000  0.000000
# 16  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
#
#        beers      best      boss  ...     today  tomorrow      very      view  \
# 0   0.000000  0.000000  0.000000  ...  0.000000  0.416445  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2   0.416445  0.000000  0.000000  ...  0.000000  0.000000  0.416445  0.000000
# 3   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  ...  0.451709  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.563317
# 10  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.587867  ...  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.563559  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#           we      went      what      will      with      work
# 0   0.416445  0.000000  0.000000  0.416445  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.451709  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.493066  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.508061  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.526279  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.563559
#
# [18 rows x 56 columns]

# %%
xtrain,xtest,ytrain,ytest = train_test_split(transformation,data.labelnum,test_size=0.2,random_state=40)

# %%
clf = MultinomialNB().fit(xtrain,ytrain)

# %%
ytest
# Out:
# 17    1
# 0     1
# 11    1
# 4     0
# Name: labelnum, dtype: int64

# %%
predicted = clf.predict(xtest)
predicted
# Out:
# array([0, 1, 1, 0], dtype=int64)

# %%
#printing accuracy, Confusion matrix, Precision and Recall
print('\n Accuracy of the classifier is',metrics.accuracy_score(ytest,predicted))
print('\n Confusion matrix')
print(metrics.confusion_matrix(ytest,predicted))
print('\n The value of Precision', metrics.precision_score(ytest,predicted))
print('\n The value of Recall', metrics.recall_score(ytest,predicted))
# Out:
#  Accuracy of the classifier is 0.75
#
#  Confusion matrix
# [[1 0]
#  [1 2]]
#
#  The value of Precision 1.0
#
#  The value of Recall 0.6666666666666666
