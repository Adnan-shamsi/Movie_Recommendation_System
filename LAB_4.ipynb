# %%
import re
from  collections import defaultdict

# %%
def open_and_clean_file_data(filename):
    sentances = []
    with open(filename,'r') as fs:
        for line in fs:
            line = line.strip().lower()
            for key, val in dict({'“': '"', '”': '"', '’': "'", '--': ','}).items():
                line = line.replace(key,val)
            line = ' '.join([word for word in re.findall("([a-z\-]+)", line)])
            if line:
                line+=" [END]"
                sentances.append(line)
    return sentances

# %%
data = open_and_clean_file_data('./data_raw.txt')

# %%
def get_tokenized_sentences(sentences):
    for sentence in sentences:
        yield sentence.split()

# %%
class UnigramCounter:
    
    def __init__(self, sentences):
        self.sentence_generator = get_tokenized_sentences(sentences)
        self.count()
        
    
    def count(self):
        self.token_count = 0
        self.counts = defaultdict(int)
        self.countOfCounts = defaultdict(int)
        
        "Actual count"
        for sentence in self.sentence_generator:
            self.token_count += len(sentence)
            for unigram in sentence: self.counts[unigram] += 1
        
        "Count of counts"
        for count in self.counts: self.countOfCounts[self.counts[count]] += 1
    
    
    
    def view_normalised_counts(self,k = 0 ,which_type='simple'):
        """"
        Normalised/ smoothing count
        
        -in case of simple unigram model    
            (actual count + k) * total_words) / (total_words + k * distict_unigrams)
    
       -in case of good turing
            ((that_unigram + 1) * number of unigrams having having count 1 extra count )/ number of unigrams having same count   
        """
        normalised_counts = {}
        if which_type.lower() == "good turing":
            for key, count in self.counts.items():
                count_num = (self.counts[key] + 1) * self.countOfCounts[count + 1]
                count_deno = self.countOfCounts[self.counts[key]]
                normalised_counts[key] = count_num/ count_deno
  
        elif which_type.lower() == 'simple':
            for count in self.counts: normalised_counts[count] = ((self.counts[count] + k) * self.token_count) / (self.token_count + k * len(self.counts))
        else:
            print("!!!!!!!!!!!!!!!!!!!!!!!ERROR!!!!!!!!!!!!!!!!!")
        return normalised_counts

# %%
class UnigramModel:
    def __init__(self, train_counter):
        self.counter = train_counter
        self.counts = train_counter.counts.copy()
        self.counts['[UNK]'] = 0
        self.distinct_words = set(self.counts.keys())

    def train(self, k=0, which_type="simple") :
        self.probs = {}
        
        for unigram, unigram_count in self.counts.items():
            if which_type == "simple":
                prob_nom = unigram_count + k
                prob_denom = self.counter.token_count + k * len(self.distinct_words)
            elif which_type == 'good turing':
                prob_nom = (unigram_count + 1) * self.counter.countOfCounts[unigram_count+1]
                prob_denom = self.counter.token_count
            else:
                print("!!!!!!!!ERROR!!!!!!!!")
            
            self.probs[unigram] = prob_nom / prob_denom
        

    def evaluate(self, evaluation_counter):
        probablity = 1
        test_counts = evaluation_counter.counts
        for unigram, test_count in test_counts.items():
            if unigram not in self.distinct_words:
                unigram = '[UNK]'
            train_prob = self.probs[unigram]
            print(f"{unigram} -> {self.probs[unigram]} probability")
            probablity = probablity*train_prob
            

        return probablity

# %% [markdown]
# # Total words and unique words

# %%
counter = UnigramCounter(data)
print(f"there are {counter.token_count} total words")
print(f"there are {len(counter.counts)} unique words")
# Out:
# there are 993 total words
# there are 336 unique words

# %% [markdown]
# ## No smoothing count

# %%
counter.view_normalised_counts()
# Out:
# {'abstract': 1.0,
#  '[END]': 35.0,
#  'fitness': 1.0,
#  'functions': 1.0,
#  'based': 1.0,
#  'on': 11.0,
#  'test': 4.0,
#  'cases': 2.0,
#  'are': 8.0,
#  'very': 1.0,
#  'common': 3.0,
#  'in': 14.0,
#  'genetic': 1.0,
#  'programming': 1.0,
#  'gp': 10.0,
#  'this': 16.0,
#  'process': 2.0,
#  'can': 10.0,
#  'be': 11.0,
#  'assimilated': 2.0,
#  'to': 28.0,
#  'a': 28.0,
#  'learning': 22.0,
#  'task': 1.0,
#  'with': 7.0,
#  'the': 84.0,
#  'inference': 1.0,
#  'of': 40.0,
#  'models': 3.0,
#  'from': 5.0,
#  'limited': 2.0,
#  'number': 2.0,
#  'samples': 1.0,
#  'paper': 4.0,
#  'is': 24.0,
#  'an': 5.0,
#  'investigation': 1.0,
#  'two': 4.0,
#  'methods': 2.0,
#  'improve': 1.0,
#  'generalization': 5.0,
#  'gp-based': 4.0,
#  'selection': 1.0,
#  'best-of-run': 3.0,
#  'individuals': 3.0,
#  'using': 5.0,
#  'three': 1.0,
#  'data': 17.0,
#  'sets': 7.0,
#  'methodology': 5.0,
#  'and': 21.0,
#  'application': 3.0,
#  'parsimony': 2.0,
#  'pressure': 2.0,
#  'order': 1.0,
#  'reduce': 2.0,
#  'complexity': 8.0,
#  'solutions': 9.0,
#  'results': 6.0,
#  'binary': 3.0,
#  'classification': 3.0,
#  'setup': 1.0,
#  'show': 1.0,
#  'that': 20.0,
#  'while': 1.0,
#  'accuracy': 1.0,
#  'preserved': 1.0,
#  'less': 3.0,
#  'variances': 1.0,
#  'compared': 2.0,
#  'baseline': 1.0,
#  'mean': 1.0,
#  'tree': 1.0,
#  'size': 2.0,
#  'obtained': 3.0,
#  'tested': 4.0,
#  'significantly': 1.0,
#  'reduced': 1.0,
#  'introduction': 1.0,
#  'particularly': 1.0,
#  'suited': 1.0,
#  'for': 6.0,
#  'problems': 5.0,
#  'tasks': 1.0,
#  'minimization': 2.0,
#  'error': 1.0,
#  'between': 3.0,
#  'desired': 1.0,
#  'outputs': 1.0,
#  'training': 10.0,
#  'ml': 5.0,
#  'terminology': 1.0,
#  'indeed': 2.0,
#  'classical': 1.0,
#  'examples': 1.0,
#  'symbolic': 1.0,
#  'regression': 2.0,
#  'boolean': 1.0,
#  'multiplexer': 1.0,
#  'artificial': 1.0,
#  'ant': 1.0,
#  'citation': 9.0,
#  'only': 2.0,
#  'simple': 2.0,
#  'instances': 1.0,
#  'well-known': 1.0,
#  'i': 1.0,
#  'e': 1.0,
#  'respectively': 1.0,
#  'reinforcement': 1.0,
#  'early': 1.0,
#  'years': 1.0,
#  'these': 5.0,
#  'were': 2.0,
#  'tackled': 1.0,
#  'single': 1.0,
#  'set': 17.0,
#  'reporting': 3.0,
#  'same': 3.0,
#  'was': 3.0,
#  'used': 10.0,
#  'evaluate': 1.0,
#  'fitnesses': 1.0,
#  'during': 4.0,
#  'evolution': 2.0,
#  'justifiable': 1.0,
#  'by': 6.0,
#  'fact': 1.0,
#  'toy': 1.0,
#  'illustrate': 1.0,
#  'potential': 1.0,
#  'community': 2.0,
#  'it': 6.0,
#  'recognized': 1.0,
#  'such': 2.0,
#  'flawed': 2.0,
#  'given': 2.0,
#  'algorithm': 9.0,
#  'overfit': 2.0,
#  'perform': 1.0,
#  'poorly': 1.0,
#  'unseen': 2.0,
#  'domain': 1.0,
#  'hence': 1.0,
#  'important': 2.0,
#  'report': 2.0,
#  'not': 3.0,
#  'stage': 1.0,
#  'what': 1.0,
#  'we': 3.0,
#  'call': 1.0,
#  'performance': 2.0,
#  'which': 5.0,
#  'good': 1.0,
#  'indicator': 1.0,
#  's': 2.0,
#  'or': 2.0,
#  'robustness': 1.0,
#  'capability': 2.0,
#  'even': 3.0,
#  'though': 2.0,
#  'has': 3.0,
#  'been': 2.0,
#  'widely': 1.0,
#  'accepted': 1.0,
#  'applied': 2.0,
#  'pr': 2.0,
#  'communities': 2.0,
#  'long': 1.0,
#  'time': 1.0,
#  'ec': 1.0,
#  'still': 1.0,
#  'lags': 1.0,
#  'behind': 2.0,
#  'publishing': 1.0,
#  'papers': 1.0,
#  'phase': 1.0,
#  'methodological': 1.0,
#  'problem': 1.0,
#  'already': 1.0,
#  'spotted': 1.0,
#  'see': 1.0,
#  'should': 2.0,
#  'future': 1.0,
#  'prevents': 1.0,
#  'algorithms': 2.0,
#  'but': 3.0,
#  'does': 1.0,
#  'prevent': 2.0,
#  'itself': 1.0,
#  'overfitting': 4.0,
#  'approach': 3.0,
#  'add': 1.0,
#  'third': 2.0,
#  'validation': 4.0,
#  'helps': 1.0,
#  'measure': 1.0,
#  'its': 1.0,
#  'useful': 1.0,
#  'interrupt': 1.0,
#  'when': 1.0,
#  'occurs': 1.0,
#  'select': 3.0,
#  'configuration': 1.0,
#  'machine': 1.0,
#  'maximizes': 1.0,
#  'performances': 1.0,
#  'commonly': 1.0,
#  'train': 1.0,
#  'classifiers': 1.0,
#  'as': 8.0,
#  'back-propagation': 1.0,
#  'neural': 1.0,
#  'networks': 1.0,
#  'easily': 1.0,
#  'ec-based': 1.0,
#  'drawback': 1.0,
#  'removes': 1.0,
#  'significant': 1.0,
#  'amount': 2.0,
#  'harmful': 1.0,
#  'richer': 1.0,
#  'more': 6.0,
#  'representative': 1.0,
#  'real': 1.0,
#  'distribution': 1.0,
#  'expected': 1.0,
#  'converge': 1.0,
#  'toward': 1.0,
#  'robust': 1.0,
#  'light': 1.0,
#  'considerations': 1.0,
#  'objective': 1.0,
#  'investigate': 2.0,
#  'effect': 2.0,
#  'another': 2.0,
#  'concern': 1.0,
#  'develop': 1.0,
#  'generate': 1.0,
#  'argument': 2.0,
#  'occam': 1.0,
#  'razor': 1.0,
#  'principle': 2.0,
#  'states': 2.0,
#  'comparable': 1.0,
#  'quality': 1.0,
#  'simplest': 1.0,
#  'must': 1.0,
#  'preferred': 1.0,
#  'minimum': 1.0,
#  'description': 1.0,
#  'length': 1.0,
#  'best': 1.0,
#  'model': 3.0,
#  'one': 1.0,
#  'minimizes': 1.0,
#  'information': 2.0,
#  'needed': 1.0,
#  'encode': 1.0,
#  'preference': 1.0,
#  'simpler': 2.0,
#  'avoidance': 1.0,
#  'closely': 1.0,
#  'related': 1.0,
#  'likely': 1.0,
#  'complex': 2.0,
#  'solution': 2.0,
#  'incorporates': 1.0,
#  'specific': 2.0,
#  'thus': 1.0,
#  'mentioned': 1.0,
#  'argumentation': 1.0,
#  'taken': 2.0,
#  'care': 1.0,
#  'too': 1.0,
#  'much': 1.0,
#  'emphasis': 1.0,
#  'minimizing': 1.0,
#  'discovery': 1.0,
#  'yet': 1.0,
#  'accurate': 1.0,
#  'there': 1.0,
#  'strong': 1.0,
#  'link': 1.0,
#  'control': 2.0,
#  'code': 3.0,
#  'bloat': 3.0,
#  'exaggerated': 1.0,
#  'growth': 1.0,
#  'program': 1.0,
#  'course': 1.0,
#  'runs': 1.0,
#  'exactly': 1.0,
#  'phenomenon': 1.0,
#  'some': 1.0,
#  'kind': 1.0,
#  'generated': 2.0,
#  'neutral': 1.0,
#  'pieces': 1.0,
#  'have': 1.0,
#  'no': 1.0,
#  'actual': 1.0,
#  'most': 1.0,
#  'mechanisms': 1.0,
#  'proposed': 2.0,
#  'also': 1.0,
#  'minimize': 1.0,
#  'study': 1.0,
#  'viewed': 1.0,
#  'specifically': 1.0,
#  'techniques': 3.0,
#  'increase': 1.0,
#  'decrease': 1.0,
#  'use': 2.0,
#  'generalize': 1.0,
#  'well': 1.0,
#  'lexicographic': 1.0,
#  'encoding': 1.0,
#  'vectors': 2.0,
#  'terminals': 1.0,
#  'mathematical': 1.0,
#  'operations': 1.0,
#  'manipulate': 1.0,
#  'branches': 1.0,
#  'six': 1.0,
#  'different': 1.0,
#  'uci': 1.0,
#  'repository': 1.0,
#  'if': 1.0,
#  'context': 1.0,
#  'argue': 1.0,
#  'they': 1.0,
#  'extended': 1.0,
#  'frequent': 1.0,
#  'situations': 1.0,
#  'where': 1.0}

# %% [markdown]
# ## No smoothing probability

# %%
model_no_smoothing = UnigramModel(counter)
model_no_smoothing.train()
model_no_smoothing.probs
# Out:
# {'abstract': 0.0010070493454179255,
#  '[END]': 0.035246727089627394,
#  'fitness': 0.0010070493454179255,
#  'functions': 0.0010070493454179255,
#  'based': 0.0010070493454179255,
#  'on': 0.011077542799597181,
#  'test': 0.004028197381671702,
#  'cases': 0.002014098690835851,
#  'are': 0.008056394763343404,
#  'very': 0.0010070493454179255,
#  'common': 0.0030211480362537764,
#  'in': 0.014098690835850957,
#  'genetic': 0.0010070493454179255,
#  'programming': 0.0010070493454179255,
#  'gp': 0.010070493454179255,
#  'this': 0.016112789526686808,
#  'process': 0.002014098690835851,
#  'can': 0.010070493454179255,
#  'be': 0.011077542799597181,
#  'assimilated': 0.002014098690835851,
#  'to': 0.028197381671701913,
#  'a': 0.028197381671701913,
#  'learning': 0.022155085599194362,
#  'task': 0.0010070493454179255,
#  'with': 0.007049345417925478,
#  'the': 0.08459214501510574,
#  'inference': 0.0010070493454179255,
#  'of': 0.04028197381671702,
#  'models': 0.0030211480362537764,
#  'from': 0.005035246727089627,
#  'limited': 0.002014098690835851,
#  'number': 0.002014098690835851,
#  'samples': 0.0010070493454179255,
#  'paper': 0.004028197381671702,
#  'is': 0.02416918429003021,
#  'an': 0.005035246727089627,
#  'investigation': 0.0010070493454179255,
#  'two': 0.004028197381671702,
#  'methods': 0.002014098690835851,
#  'improve': 0.0010070493454179255,
#  'generalization': 0.005035246727089627,
#  'gp-based': 0.004028197381671702,
#  'selection': 0.0010070493454179255,
#  'best-of-run': 0.0030211480362537764,
#  'individuals': 0.0030211480362537764,
#  'using': 0.005035246727089627,
#  'three': 0.0010070493454179255,
#  'data': 0.017119838872104734,
#  'sets': 0.007049345417925478,
#  'methodology': 0.005035246727089627,
#  'and': 0.021148036253776436,
#  'application': 0.0030211480362537764,
#  'parsimony': 0.002014098690835851,
#  'pressure': 0.002014098690835851,
#  'order': 0.0010070493454179255,
#  'reduce': 0.002014098690835851,
#  'complexity': 0.008056394763343404,
#  'solutions': 0.00906344410876133,
#  'results': 0.006042296072507553,
#  'binary': 0.0030211480362537764,
#  'classification': 0.0030211480362537764,
#  'setup': 0.0010070493454179255,
#  'show': 0.0010070493454179255,
#  'that': 0.02014098690835851,
#  'while': 0.0010070493454179255,
#  'accuracy': 0.0010070493454179255,
#  'preserved': 0.0010070493454179255,
#  'less': 0.0030211480362537764,
#  'variances': 0.0010070493454179255,
#  'compared': 0.002014098690835851,
#  'baseline': 0.0010070493454179255,
#  'mean': 0.0010070493454179255,
#  'tree': 0.0010070493454179255,
#  'size': 0.002014098690835851,
#  'obtained': 0.0030211480362537764,
#  'tested': 0.004028197381671702,
#  'significantly': 0.0010070493454179255,
#  'reduced': 0.0010070493454179255,
#  'introduction': 0.0010070493454179255,
#  'particularly': 0.0010070493454179255,
#  'suited': 0.0010070493454179255,
#  'for': 0.006042296072507553,
#  'problems': 0.005035246727089627,
#  'tasks': 0.0010070493454179255,
#  'minimization': 0.002014098690835851,
#  'error': 0.0010070493454179255,
#  'between': 0.0030211480362537764,
#  'desired': 0.0010070493454179255,
#  'outputs': 0.0010070493454179255,
#  'training': 0.010070493454179255,
#  'ml': 0.005035246727089627,
#  'terminology': 0.0010070493454179255,
#  'indeed': 0.002014098690835851,
#  'classical': 0.0010070493454179255,
#  'examples': 0.0010070493454179255,
#  'symbolic': 0.0010070493454179255,
#  'regression': 0.002014098690835851,
#  'boolean': 0.0010070493454179255,
#  'multiplexer': 0.0010070493454179255,
#  'artificial': 0.0010070493454179255,
#  'ant': 0.0010070493454179255,
#  'citation': 0.00906344410876133,
#  'only': 0.002014098690835851,
#  'simple': 0.002014098690835851,
#  'instances': 0.0010070493454179255,
#  'well-known': 0.0010070493454179255,
#  'i': 0.0010070493454179255,
#  'e': 0.0010070493454179255,
#  'respectively': 0.0010070493454179255,
#  'reinforcement': 0.0010070493454179255,
#  'early': 0.0010070493454179255,
#  'years': 0.0010070493454179255,
#  'these': 0.005035246727089627,
#  'were': 0.002014098690835851,
#  'tackled': 0.0010070493454179255,
#  'single': 0.0010070493454179255,
#  'set': 0.017119838872104734,
#  'reporting': 0.0030211480362537764,
#  'same': 0.0030211480362537764,
#  'was': 0.0030211480362537764,
#  'used': 0.010070493454179255,
#  'evaluate': 0.0010070493454179255,
#  'fitnesses': 0.0010070493454179255,
#  'during': 0.004028197381671702,
#  'evolution': 0.002014098690835851,
#  'justifiable': 0.0010070493454179255,
#  'by': 0.006042296072507553,
#  'fact': 0.0010070493454179255,
#  'toy': 0.0010070493454179255,
#  'illustrate': 0.0010070493454179255,
#  'potential': 0.0010070493454179255,
#  'community': 0.002014098690835851,
#  'it': 0.006042296072507553,
#  'recognized': 0.0010070493454179255,
#  'such': 0.002014098690835851,
#  'flawed': 0.002014098690835851,
#  'given': 0.002014098690835851,
#  'algorithm': 0.00906344410876133,
#  'overfit': 0.002014098690835851,
#  'perform': 0.0010070493454179255,
#  'poorly': 0.0010070493454179255,
#  'unseen': 0.002014098690835851,
#  'domain': 0.0010070493454179255,
#  'hence': 0.0010070493454179255,
#  'important': 0.002014098690835851,
#  'report': 0.002014098690835851,
#  'not': 0.0030211480362537764,
#  'stage': 0.0010070493454179255,
#  'what': 0.0010070493454179255,
#  'we': 0.0030211480362537764,
#  'call': 0.0010070493454179255,
#  'performance': 0.002014098690835851,
#  'which': 0.005035246727089627,
#  'good': 0.0010070493454179255,
#  'indicator': 0.0010070493454179255,
#  's': 0.002014098690835851,
#  'or': 0.002014098690835851,
#  'robustness': 0.0010070493454179255,
#  'capability': 0.002014098690835851,
#  'even': 0.0030211480362537764,
#  'though': 0.002014098690835851,
#  'has': 0.0030211480362537764,
#  'been': 0.002014098690835851,
#  'widely': 0.0010070493454179255,
#  'accepted': 0.0010070493454179255,
#  'applied': 0.002014098690835851,
#  'pr': 0.002014098690835851,
#  'communities': 0.002014098690835851,
#  'long': 0.0010070493454179255,
#  'time': 0.0010070493454179255,
#  'ec': 0.0010070493454179255,
#  'still': 0.0010070493454179255,
#  'lags': 0.0010070493454179255,
#  'behind': 0.002014098690835851,
#  'publishing': 0.0010070493454179255,
#  'papers': 0.0010070493454179255,
#  'phase': 0.0010070493454179255,
#  'methodological': 0.0010070493454179255,
#  'problem': 0.0010070493454179255,
#  'already': 0.0010070493454179255,
#  'spotted': 0.0010070493454179255,
#  'see': 0.0010070493454179255,
#  'should': 0.002014098690835851,
#  'future': 0.0010070493454179255,
#  'prevents': 0.0010070493454179255,
#  'algorithms': 0.002014098690835851,
#  'but': 0.0030211480362537764,
#  'does': 0.0010070493454179255,
#  'prevent': 0.002014098690835851,
#  'itself': 0.0010070493454179255,
#  'overfitting': 0.004028197381671702,
#  'approach': 0.0030211480362537764,
#  'add': 0.0010070493454179255,
#  'third': 0.002014098690835851,
#  'validation': 0.004028197381671702,
#  'helps': 0.0010070493454179255,
#  'measure': 0.0010070493454179255,
#  'its': 0.0010070493454179255,
#  'useful': 0.0010070493454179255,
#  'interrupt': 0.0010070493454179255,
#  'when': 0.0010070493454179255,
#  'occurs': 0.0010070493454179255,
#  'select': 0.0030211480362537764,
#  'configuration': 0.0010070493454179255,
#  'machine': 0.0010070493454179255,
#  'maximizes': 0.0010070493454179255,
#  'performances': 0.0010070493454179255,
#  'commonly': 0.0010070493454179255,
#  'train': 0.0010070493454179255,
#  'classifiers': 0.0010070493454179255,
#  'as': 0.008056394763343404,
#  'back-propagation': 0.0010070493454179255,
#  'neural': 0.0010070493454179255,
#  'networks': 0.0010070493454179255,
#  'easily': 0.0010070493454179255,
#  'ec-based': 0.0010070493454179255,
#  'drawback': 0.0010070493454179255,
#  'removes': 0.0010070493454179255,
#  'significant': 0.0010070493454179255,
#  'amount': 0.002014098690835851,
#  'harmful': 0.0010070493454179255,
#  'richer': 0.0010070493454179255,
#  'more': 0.006042296072507553,
#  'representative': 0.0010070493454179255,
#  'real': 0.0010070493454179255,
#  'distribution': 0.0010070493454179255,
#  'expected': 0.0010070493454179255,
#  'converge': 0.0010070493454179255,
#  'toward': 0.0010070493454179255,
#  'robust': 0.0010070493454179255,
#  'light': 0.0010070493454179255,
#  'considerations': 0.0010070493454179255,
#  'objective': 0.0010070493454179255,
#  'investigate': 0.002014098690835851,
#  'effect': 0.002014098690835851,
#  'another': 0.002014098690835851,
#  'concern': 0.0010070493454179255,
#  'develop': 0.0010070493454179255,
#  'generate': 0.0010070493454179255,
#  'argument': 0.002014098690835851,
#  'occam': 0.0010070493454179255,
#  'razor': 0.0010070493454179255,
#  'principle': 0.002014098690835851,
#  'states': 0.002014098690835851,
#  'comparable': 0.0010070493454179255,
#  'quality': 0.0010070493454179255,
#  'simplest': 0.0010070493454179255,
#  'must': 0.0010070493454179255,
#  'preferred': 0.0010070493454179255,
#  'minimum': 0.0010070493454179255,
#  'description': 0.0010070493454179255,
#  'length': 0.0010070493454179255,
#  'best': 0.0010070493454179255,
#  'model': 0.0030211480362537764,
#  'one': 0.0010070493454179255,
#  'minimizes': 0.0010070493454179255,
#  'information': 0.002014098690835851,
#  'needed': 0.0010070493454179255,
#  'encode': 0.0010070493454179255,
#  'preference': 0.0010070493454179255,
#  'simpler': 0.002014098690835851,
#  'avoidance': 0.0010070493454179255,
#  'closely': 0.0010070493454179255,
#  'related': 0.0010070493454179255,
#  'likely': 0.0010070493454179255,
#  'complex': 0.002014098690835851,
#  'solution': 0.002014098690835851,
#  'incorporates': 0.0010070493454179255,
#  'specific': 0.002014098690835851,
#  'thus': 0.0010070493454179255,
#  'mentioned': 0.0010070493454179255,
#  'argumentation': 0.0010070493454179255,
#  'taken': 0.002014098690835851,
#  'care': 0.0010070493454179255,
#  'too': 0.0010070493454179255,
#  'much': 0.0010070493454179255,
#  'emphasis': 0.0010070493454179255,
#  'minimizing': 0.0010070493454179255,
#  'discovery': 0.0010070493454179255,
#  'yet': 0.0010070493454179255,
#  'accurate': 0.0010070493454179255,
#  'there': 0.0010070493454179255,
#  'strong': 0.0010070493454179255,
#  'link': 0.0010070493454179255,
#  'control': 0.002014098690835851,
#  'code': 0.0030211480362537764,
#  'bloat': 0.0030211480362537764,
#  'exaggerated': 0.0010070493454179255,
#  'growth': 0.0010070493454179255,
#  'program': 0.0010070493454179255,
#  'course': 0.0010070493454179255,
#  'runs': 0.0010070493454179255,
#  'exactly': 0.0010070493454179255,
#  'phenomenon': 0.0010070493454179255,
#  'some': 0.0010070493454179255,
#  'kind': 0.0010070493454179255,
#  'generated': 0.002014098690835851,
#  'neutral': 0.0010070493454179255,
#  'pieces': 0.0010070493454179255,
#  'have': 0.0010070493454179255,
#  'no': 0.0010070493454179255,
#  'actual': 0.0010070493454179255,
#  'most': 0.0010070493454179255,
#  'mechanisms': 0.0010070493454179255,
#  'proposed': 0.002014098690835851,
#  'also': 0.0010070493454179255,
#  'minimize': 0.0010070493454179255,
#  'study': 0.0010070493454179255,
#  'viewed': 0.0010070493454179255,
#  'specifically': 0.0010070493454179255,
#  'techniques': 0.0030211480362537764,
#  'increase': 0.0010070493454179255,
#  'decrease': 0.0010070493454179255,
#  'use': 0.002014098690835851,
#  'generalize': 0.0010070493454179255,
#  'well': 0.0010070493454179255,
#  'lexicographic': 0.0010070493454179255,
#  'encoding': 0.0010070493454179255,
#  'vectors': 0.002014098690835851,
#  'terminals': 0.0010070493454179255,
#  'mathematical': 0.0010070493454179255,
#  'operations': 0.0010070493454179255,
#  'manipulate': 0.0010070493454179255,
#  'branches': 0.0010070493454179255,
#  'six': 0.0010070493454179255,
#  'different': 0.0010070493454179255,
#  'uci': 0.0010070493454179255,
#  'repository': 0.0010070493454179255,
#  'if': 0.0010070493454179255,
#  'context': 0.0010070493454179255,
#  'argue': 0.0010070493454179255,
#  'they': 0.0010070493454179255,
#  'extended': 0.0010070493454179255,
#  'frequent': 0.0010070493454179255,
#  'situations': 0.0010070493454179255,
#  'where': 0.0010070493454179255,
#  '[UNK]': 0.0}

# %% [markdown]
# ## Add 1 count

# %%
counter.view_normalised_counts(k=1)
# Out:
# {'abstract': 1.4943566591422122,
#  '[END]': 26.89841986455982,
#  'fitness': 1.4943566591422122,
#  'functions': 1.4943566591422122,
#  'based': 1.4943566591422122,
#  'on': 8.966139954853274,
#  'test': 3.7358916478555306,
#  'cases': 2.2415349887133185,
#  'are': 6.724604966139955,
#  'very': 1.4943566591422122,
#  'common': 2.9887133182844243,
#  'in': 11.207674943566591,
#  'genetic': 1.4943566591422122,
#  'programming': 1.4943566591422122,
#  'gp': 8.218961625282168,
#  'this': 12.702031602708804,
#  'process': 2.2415349887133185,
#  'can': 8.218961625282168,
#  'be': 8.966139954853274,
#  'assimilated': 2.2415349887133185,
#  'to': 21.668171557562076,
#  'a': 21.668171557562076,
#  'learning': 17.18510158013544,
#  'task': 1.4943566591422122,
#  'with': 5.977426636568849,
#  'the': 63.51015801354402,
#  'inference': 1.4943566591422122,
#  'of': 30.63431151241535,
#  'models': 2.9887133182844243,
#  'from': 4.483069977426637,
#  'limited': 2.2415349887133185,
#  'number': 2.2415349887133185,
#  'samples': 1.4943566591422122,
#  'paper': 3.7358916478555306,
#  'is': 18.679458239277654,
#  'an': 4.483069977426637,
#  'investigation': 1.4943566591422122,
#  'two': 3.7358916478555306,
#  'methods': 2.2415349887133185,
#  'improve': 1.4943566591422122,
#  'generalization': 4.483069977426637,
#  'gp-based': 3.7358916478555306,
#  'selection': 1.4943566591422122,
#  'best-of-run': 2.9887133182844243,
#  'individuals': 2.9887133182844243,
#  'using': 4.483069977426637,
#  'three': 1.4943566591422122,
#  'data': 13.44920993227991,
#  'sets': 5.977426636568849,
#  'methodology': 4.483069977426637,
#  'and': 16.437923250564335,
#  'application': 2.9887133182844243,
#  'parsimony': 2.2415349887133185,
#  'pressure': 2.2415349887133185,
#  'order': 1.4943566591422122,
#  'reduce': 2.2415349887133185,
#  'complexity': 6.724604966139955,
#  'solutions': 7.471783295711061,
#  'results': 5.230248306997742,
#  'binary': 2.9887133182844243,
#  'classification': 2.9887133182844243,
#  'setup': 1.4943566591422122,
#  'show': 1.4943566591422122,
#  'that': 15.690744920993229,
#  'while': 1.4943566591422122,
#  'accuracy': 1.4943566591422122,
#  'preserved': 1.4943566591422122,
#  'less': 2.9887133182844243,
#  'variances': 1.4943566591422122,
#  'compared': 2.2415349887133185,
#  'baseline': 1.4943566591422122,
#  'mean': 1.4943566591422122,
#  'tree': 1.4943566591422122,
#  'size': 2.2415349887133185,
#  'obtained': 2.9887133182844243,
#  'tested': 3.7358916478555306,
#  'significantly': 1.4943566591422122,
#  'reduced': 1.4943566591422122,
#  'introduction': 1.4943566591422122,
#  'particularly': 1.4943566591422122,
#  'suited': 1.4943566591422122,
#  'for': 5.230248306997742,
#  'problems': 4.483069977426637,
#  'tasks': 1.4943566591422122,
#  'minimization': 2.2415349887133185,
#  'error': 1.4943566591422122,
#  'between': 2.9887133182844243,
#  'desired': 1.4943566591422122,
#  'outputs': 1.4943566591422122,
#  'training': 8.218961625282168,
#  'ml': 4.483069977426637,
#  'terminology': 1.4943566591422122,
#  'indeed': 2.2415349887133185,
#  'classical': 1.4943566591422122,
#  'examples': 1.4943566591422122,
#  'symbolic': 1.4943566591422122,
#  'regression': 2.2415349887133185,
#  'boolean': 1.4943566591422122,
#  'multiplexer': 1.4943566591422122,
#  'artificial': 1.4943566591422122,
#  'ant': 1.4943566591422122,
#  'citation': 7.471783295711061,
#  'only': 2.2415349887133185,
#  'simple': 2.2415349887133185,
#  'instances': 1.4943566591422122,
#  'well-known': 1.4943566591422122,
#  'i': 1.4943566591422122,
#  'e': 1.4943566591422122,
#  'respectively': 1.4943566591422122,
#  'reinforcement': 1.4943566591422122,
#  'early': 1.4943566591422122,
#  'years': 1.4943566591422122,
#  'these': 4.483069977426637,
#  'were': 2.2415349887133185,
#  'tackled': 1.4943566591422122,
#  'single': 1.4943566591422122,
#  'set': 13.44920993227991,
#  'reporting': 2.9887133182844243,
#  'same': 2.9887133182844243,
#  'was': 2.9887133182844243,
#  'used': 8.218961625282168,
#  'evaluate': 1.4943566591422122,
#  'fitnesses': 1.4943566591422122,
#  'during': 3.7358916478555306,
#  'evolution': 2.2415349887133185,
#  'justifiable': 1.4943566591422122,
#  'by': 5.230248306997742,
#  'fact': 1.4943566591422122,
#  'toy': 1.4943566591422122,
#  'illustrate': 1.4943566591422122,
#  'potential': 1.4943566591422122,
#  'community': 2.2415349887133185,
#  'it': 5.230248306997742,
#  'recognized': 1.4943566591422122,
#  'such': 2.2415349887133185,
#  'flawed': 2.2415349887133185,
#  'given': 2.2415349887133185,
#  'algorithm': 7.471783295711061,
#  'overfit': 2.2415349887133185,
#  'perform': 1.4943566591422122,
#  'poorly': 1.4943566591422122,
#  'unseen': 2.2415349887133185,
#  'domain': 1.4943566591422122,
#  'hence': 1.4943566591422122,
#  'important': 2.2415349887133185,
#  'report': 2.2415349887133185,
#  'not': 2.9887133182844243,
#  'stage': 1.4943566591422122,
#  'what': 1.4943566591422122,
#  'we': 2.9887133182844243,
#  'call': 1.4943566591422122,
#  'performance': 2.2415349887133185,
#  'which': 4.483069977426637,
#  'good': 1.4943566591422122,
#  'indicator': 1.4943566591422122,
#  's': 2.2415349887133185,
#  'or': 2.2415349887133185,
#  'robustness': 1.4943566591422122,
#  'capability': 2.2415349887133185,
#  'even': 2.9887133182844243,
#  'though': 2.2415349887133185,
#  'has': 2.9887133182844243,
#  'been': 2.2415349887133185,
#  'widely': 1.4943566591422122,
#  'accepted': 1.4943566591422122,
#  'applied': 2.2415349887133185,
#  'pr': 2.2415349887133185,
#  'communities': 2.2415349887133185,
#  'long': 1.4943566591422122,
#  'time': 1.4943566591422122,
#  'ec': 1.4943566591422122,
#  'still': 1.4943566591422122,
#  'lags': 1.4943566591422122,
#  'behind': 2.2415349887133185,
#  'publishing': 1.4943566591422122,
#  'papers': 1.4943566591422122,
#  'phase': 1.4943566591422122,
#  'methodological': 1.4943566591422122,
#  'problem': 1.4943566591422122,
#  'already': 1.4943566591422122,
#  'spotted': 1.4943566591422122,
#  'see': 1.4943566591422122,
#  'should': 2.2415349887133185,
#  'future': 1.4943566591422122,
#  'prevents': 1.4943566591422122,
#  'algorithms': 2.2415349887133185,
#  'but': 2.9887133182844243,
#  'does': 1.4943566591422122,
#  'prevent': 2.2415349887133185,
#  'itself': 1.4943566591422122,
#  'overfitting': 3.7358916478555306,
#  'approach': 2.9887133182844243,
#  'add': 1.4943566591422122,
#  'third': 2.2415349887133185,
#  'validation': 3.7358916478555306,
#  'helps': 1.4943566591422122,
#  'measure': 1.4943566591422122,
#  'its': 1.4943566591422122,
#  'useful': 1.4943566591422122,
#  'interrupt': 1.4943566591422122,
#  'when': 1.4943566591422122,
#  'occurs': 1.4943566591422122,
#  'select': 2.9887133182844243,
#  'configuration': 1.4943566591422122,
#  'machine': 1.4943566591422122,
#  'maximizes': 1.4943566591422122,
#  'performances': 1.4943566591422122,
#  'commonly': 1.4943566591422122,
#  'train': 1.4943566591422122,
#  'classifiers': 1.4943566591422122,
#  'as': 6.724604966139955,
#  'back-propagation': 1.4943566591422122,
#  'neural': 1.4943566591422122,
#  'networks': 1.4943566591422122,
#  'easily': 1.4943566591422122,
#  'ec-based': 1.4943566591422122,
#  'drawback': 1.4943566591422122,
#  'removes': 1.4943566591422122,
#  'significant': 1.4943566591422122,
#  'amount': 2.2415349887133185,
#  'harmful': 1.4943566591422122,
#  'richer': 1.4943566591422122,
#  'more': 5.230248306997742,
#  'representative': 1.4943566591422122,
#  'real': 1.4943566591422122,
#  'distribution': 1.4943566591422122,
#  'expected': 1.4943566591422122,
#  'converge': 1.4943566591422122,
#  'toward': 1.4943566591422122,
#  'robust': 1.4943566591422122,
#  'light': 1.4943566591422122,
#  'considerations': 1.4943566591422122,
#  'objective': 1.4943566591422122,
#  'investigate': 2.2415349887133185,
#  'effect': 2.2415349887133185,
#  'another': 2.2415349887133185,
#  'concern': 1.4943566591422122,
#  'develop': 1.4943566591422122,
#  'generate': 1.4943566591422122,
#  'argument': 2.2415349887133185,
#  'occam': 1.4943566591422122,
#  'razor': 1.4943566591422122,
#  'principle': 2.2415349887133185,
#  'states': 2.2415349887133185,
#  'comparable': 1.4943566591422122,
#  'quality': 1.4943566591422122,
#  'simplest': 1.4943566591422122,
#  'must': 1.4943566591422122,
#  'preferred': 1.4943566591422122,
#  'minimum': 1.4943566591422122,
#  'description': 1.4943566591422122,
#  'length': 1.4943566591422122,
#  'best': 1.4943566591422122,
#  'model': 2.9887133182844243,
#  'one': 1.4943566591422122,
#  'minimizes': 1.4943566591422122,
#  'information': 2.2415349887133185,
#  'needed': 1.4943566591422122,
#  'encode': 1.4943566591422122,
#  'preference': 1.4943566591422122,
#  'simpler': 2.2415349887133185,
#  'avoidance': 1.4943566591422122,
#  'closely': 1.4943566591422122,
#  'related': 1.4943566591422122,
#  'likely': 1.4943566591422122,
#  'complex': 2.2415349887133185,
#  'solution': 2.2415349887133185,
#  'incorporates': 1.4943566591422122,
#  'specific': 2.2415349887133185,
#  'thus': 1.4943566591422122,
#  'mentioned': 1.4943566591422122,
#  'argumentation': 1.4943566591422122,
#  'taken': 2.2415349887133185,
#  'care': 1.4943566591422122,
#  'too': 1.4943566591422122,
#  'much': 1.4943566591422122,
#  'emphasis': 1.4943566591422122,
#  'minimizing': 1.4943566591422122,
#  'discovery': 1.4943566591422122,
#  'yet': 1.4943566591422122,
#  'accurate': 1.4943566591422122,
#  'there': 1.4943566591422122,
#  'strong': 1.4943566591422122,
#  'link': 1.4943566591422122,
#  'control': 2.2415349887133185,
#  'code': 2.9887133182844243,
#  'bloat': 2.9887133182844243,
#  'exaggerated': 1.4943566591422122,
#  'growth': 1.4943566591422122,
#  'program': 1.4943566591422122,
#  'course': 1.4943566591422122,
#  'runs': 1.4943566591422122,
#  'exactly': 1.4943566591422122,
#  'phenomenon': 1.4943566591422122,
#  'some': 1.4943566591422122,
#  'kind': 1.4943566591422122,
#  'generated': 2.2415349887133185,
#  'neutral': 1.4943566591422122,
#  'pieces': 1.4943566591422122,
#  'have': 1.4943566591422122,
#  'no': 1.4943566591422122,
#  'actual': 1.4943566591422122,
#  'most': 1.4943566591422122,
#  'mechanisms': 1.4943566591422122,
#  'proposed': 2.2415349887133185,
#  'also': 1.4943566591422122,
#  'minimize': 1.4943566591422122,
#  'study': 1.4943566591422122,
#  'viewed': 1.4943566591422122,
#  'specifically': 1.4943566591422122,
#  'techniques': 2.9887133182844243,
#  'increase': 1.4943566591422122,
#  'decrease': 1.4943566591422122,
#  'use': 2.2415349887133185,
#  'generalize': 1.4943566591422122,
#  'well': 1.4943566591422122,
#  'lexicographic': 1.4943566591422122,
#  'encoding': 1.4943566591422122,
#  'vectors': 2.2415349887133185,
#  'terminals': 1.4943566591422122,
#  'mathematical': 1.4943566591422122,
#  'operations': 1.4943566591422122,
#  'manipulate': 1.4943566591422122,
#  'branches': 1.4943566591422122,
#  'six': 1.4943566591422122,
#  'different': 1.4943566591422122,
#  'uci': 1.4943566591422122,
#  'repository': 1.4943566591422122,
#  'if': 1.4943566591422122,
#  'context': 1.4943566591422122,
#  'argue': 1.4943566591422122,
#  'they': 1.4943566591422122,
#  'extended': 1.4943566591422122,
#  'frequent': 1.4943566591422122,
#  'situations': 1.4943566591422122,
#  'where': 1.4943566591422122}

# %% [markdown]
# ## Add 1 smoothing probability

# %%
model_add_one = UnigramModel(counter)
model_add_one.train(k=1)
model_add_one.probs
# Out:
# {'abstract': 0.0015037593984962407,
#  '[END]': 0.02706766917293233,
#  'fitness': 0.0015037593984962407,
#  'functions': 0.0015037593984962407,
#  'based': 0.0015037593984962407,
#  'on': 0.009022556390977444,
#  'test': 0.0037593984962406013,
#  'cases': 0.002255639097744361,
#  'are': 0.006766917293233083,
#  'very': 0.0015037593984962407,
#  'common': 0.0030075187969924814,
#  'in': 0.011278195488721804,
#  'genetic': 0.0015037593984962407,
#  'programming': 0.0015037593984962407,
#  'gp': 0.008270676691729323,
#  'this': 0.012781954887218045,
#  'process': 0.002255639097744361,
#  'can': 0.008270676691729323,
#  'be': 0.009022556390977444,
#  'assimilated': 0.002255639097744361,
#  'to': 0.02180451127819549,
#  'a': 0.02180451127819549,
#  'learning': 0.017293233082706767,
#  'task': 0.0015037593984962407,
#  'with': 0.006015037593984963,
#  'the': 0.06390977443609022,
#  'inference': 0.0015037593984962407,
#  'of': 0.030827067669172932,
#  'models': 0.0030075187969924814,
#  'from': 0.004511278195488722,
#  'limited': 0.002255639097744361,
#  'number': 0.002255639097744361,
#  'samples': 0.0015037593984962407,
#  'paper': 0.0037593984962406013,
#  'is': 0.018796992481203006,
#  'an': 0.004511278195488722,
#  'investigation': 0.0015037593984962407,
#  'two': 0.0037593984962406013,
#  'methods': 0.002255639097744361,
#  'improve': 0.0015037593984962407,
#  'generalization': 0.004511278195488722,
#  'gp-based': 0.0037593984962406013,
#  'selection': 0.0015037593984962407,
#  'best-of-run': 0.0030075187969924814,
#  'individuals': 0.0030075187969924814,
#  'using': 0.004511278195488722,
#  'three': 0.0015037593984962407,
#  'data': 0.013533834586466165,
#  'sets': 0.006015037593984963,
#  'methodology': 0.004511278195488722,
#  'and': 0.016541353383458645,
#  'application': 0.0030075187969924814,
#  'parsimony': 0.002255639097744361,
#  'pressure': 0.002255639097744361,
#  'order': 0.0015037593984962407,
#  'reduce': 0.002255639097744361,
#  'complexity': 0.006766917293233083,
#  'solutions': 0.007518796992481203,
#  'results': 0.005263157894736842,
#  'binary': 0.0030075187969924814,
#  'classification': 0.0030075187969924814,
#  'setup': 0.0015037593984962407,
#  'show': 0.0015037593984962407,
#  'that': 0.015789473684210527,
#  'while': 0.0015037593984962407,
#  'accuracy': 0.0015037593984962407,
#  'preserved': 0.0015037593984962407,
#  'less': 0.0030075187969924814,
#  'variances': 0.0015037593984962407,
#  'compared': 0.002255639097744361,
#  'baseline': 0.0015037593984962407,
#  'mean': 0.0015037593984962407,
#  'tree': 0.0015037593984962407,
#  'size': 0.002255639097744361,
#  'obtained': 0.0030075187969924814,
#  'tested': 0.0037593984962406013,
#  'significantly': 0.0015037593984962407,
#  'reduced': 0.0015037593984962407,
#  'introduction': 0.0015037593984962407,
#  'particularly': 0.0015037593984962407,
#  'suited': 0.0015037593984962407,
#  'for': 0.005263157894736842,
#  'problems': 0.004511278195488722,
#  'tasks': 0.0015037593984962407,
#  'minimization': 0.002255639097744361,
#  'error': 0.0015037593984962407,
#  'between': 0.0030075187969924814,
#  'desired': 0.0015037593984962407,
#  'outputs': 0.0015037593984962407,
#  'training': 0.008270676691729323,
#  'ml': 0.004511278195488722,
#  'terminology': 0.0015037593984962407,
#  'indeed': 0.002255639097744361,
#  'classical': 0.0015037593984962407,
#  'examples': 0.0015037593984962407,
#  'symbolic': 0.0015037593984962407,
#  'regression': 0.002255639097744361,
#  'boolean': 0.0015037593984962407,
#  'multiplexer': 0.0015037593984962407,
#  'artificial': 0.0015037593984962407,
#  'ant': 0.0015037593984962407,
#  'citation': 0.007518796992481203,
#  'only': 0.002255639097744361,
#  'simple': 0.002255639097744361,
#  'instances': 0.0015037593984962407,
#  'well-known': 0.0015037593984962407,
#  'i': 0.0015037593984962407,
#  'e': 0.0015037593984962407,
#  'respectively': 0.0015037593984962407,
#  'reinforcement': 0.0015037593984962407,
#  'early': 0.0015037593984962407,
#  'years': 0.0015037593984962407,
#  'these': 0.004511278195488722,
#  'were': 0.002255639097744361,
#  'tackled': 0.0015037593984962407,
#  'single': 0.0015037593984962407,
#  'set': 0.013533834586466165,
#  'reporting': 0.0030075187969924814,
#  'same': 0.0030075187969924814,
#  'was': 0.0030075187969924814,
#  'used': 0.008270676691729323,
#  'evaluate': 0.0015037593984962407,
#  'fitnesses': 0.0015037593984962407,
#  'during': 0.0037593984962406013,
#  'evolution': 0.002255639097744361,
#  'justifiable': 0.0015037593984962407,
#  'by': 0.005263157894736842,
#  'fact': 0.0015037593984962407,
#  'toy': 0.0015037593984962407,
#  'illustrate': 0.0015037593984962407,
#  'potential': 0.0015037593984962407,
#  'community': 0.002255639097744361,
#  'it': 0.005263157894736842,
#  'recognized': 0.0015037593984962407,
#  'such': 0.002255639097744361,
#  'flawed': 0.002255639097744361,
#  'given': 0.002255639097744361,
#  'algorithm': 0.007518796992481203,
#  'overfit': 0.002255639097744361,
#  'perform': 0.0015037593984962407,
#  'poorly': 0.0015037593984962407,
#  'unseen': 0.002255639097744361,
#  'domain': 0.0015037593984962407,
#  'hence': 0.0015037593984962407,
#  'important': 0.002255639097744361,
#  'report': 0.002255639097744361,
#  'not': 0.0030075187969924814,
#  'stage': 0.0015037593984962407,
#  'what': 0.0015037593984962407,
#  'we': 0.0030075187969924814,
#  'call': 0.0015037593984962407,
#  'performance': 0.002255639097744361,
#  'which': 0.004511278195488722,
#  'good': 0.0015037593984962407,
#  'indicator': 0.0015037593984962407,
#  's': 0.002255639097744361,
#  'or': 0.002255639097744361,
#  'robustness': 0.0015037593984962407,
#  'capability': 0.002255639097744361,
#  'even': 0.0030075187969924814,
#  'though': 0.002255639097744361,
#  'has': 0.0030075187969924814,
#  'been': 0.002255639097744361,
#  'widely': 0.0015037593984962407,
#  'accepted': 0.0015037593984962407,
#  'applied': 0.002255639097744361,
#  'pr': 0.002255639097744361,
#  'communities': 0.002255639097744361,
#  'long': 0.0015037593984962407,
#  'time': 0.0015037593984962407,
#  'ec': 0.0015037593984962407,
#  'still': 0.0015037593984962407,
#  'lags': 0.0015037593984962407,
#  'behind': 0.002255639097744361,
#  'publishing': 0.0015037593984962407,
#  'papers': 0.0015037593984962407,
#  'phase': 0.0015037593984962407,
#  'methodological': 0.0015037593984962407,
#  'problem': 0.0015037593984962407,
#  'already': 0.0015037593984962407,
#  'spotted': 0.0015037593984962407,
#  'see': 0.0015037593984962407,
#  'should': 0.002255639097744361,
#  'future': 0.0015037593984962407,
#  'prevents': 0.0015037593984962407,
#  'algorithms': 0.002255639097744361,
#  'but': 0.0030075187969924814,
#  'does': 0.0015037593984962407,
#  'prevent': 0.002255639097744361,
#  'itself': 0.0015037593984962407,
#  'overfitting': 0.0037593984962406013,
#  'approach': 0.0030075187969924814,
#  'add': 0.0015037593984962407,
#  'third': 0.002255639097744361,
#  'validation': 0.0037593984962406013,
#  'helps': 0.0015037593984962407,
#  'measure': 0.0015037593984962407,
#  'its': 0.0015037593984962407,
#  'useful': 0.0015037593984962407,
#  'interrupt': 0.0015037593984962407,
#  'when': 0.0015037593984962407,
#  'occurs': 0.0015037593984962407,
#  'select': 0.0030075187969924814,
#  'configuration': 0.0015037593984962407,
#  'machine': 0.0015037593984962407,
#  'maximizes': 0.0015037593984962407,
#  'performances': 0.0015037593984962407,
#  'commonly': 0.0015037593984962407,
#  'train': 0.0015037593984962407,
#  'classifiers': 0.0015037593984962407,
#  'as': 0.006766917293233083,
#  'back-propagation': 0.0015037593984962407,
#  'neural': 0.0015037593984962407,
#  'networks': 0.0015037593984962407,
#  'easily': 0.0015037593984962407,
#  'ec-based': 0.0015037593984962407,
#  'drawback': 0.0015037593984962407,
#  'removes': 0.0015037593984962407,
#  'significant': 0.0015037593984962407,
#  'amount': 0.002255639097744361,
#  'harmful': 0.0015037593984962407,
#  'richer': 0.0015037593984962407,
#  'more': 0.005263157894736842,
#  'representative': 0.0015037593984962407,
#  'real': 0.0015037593984962407,
#  'distribution': 0.0015037593984962407,
#  'expected': 0.0015037593984962407,
#  'converge': 0.0015037593984962407,
#  'toward': 0.0015037593984962407,
#  'robust': 0.0015037593984962407,
#  'light': 0.0015037593984962407,
#  'considerations': 0.0015037593984962407,
#  'objective': 0.0015037593984962407,
#  'investigate': 0.002255639097744361,
#  'effect': 0.002255639097744361,
#  'another': 0.002255639097744361,
#  'concern': 0.0015037593984962407,
#  'develop': 0.0015037593984962407,
#  'generate': 0.0015037593984962407,
#  'argument': 0.002255639097744361,
#  'occam': 0.0015037593984962407,
#  'razor': 0.0015037593984962407,
#  'principle': 0.002255639097744361,
#  'states': 0.002255639097744361,
#  'comparable': 0.0015037593984962407,
#  'quality': 0.0015037593984962407,
#  'simplest': 0.0015037593984962407,
#  'must': 0.0015037593984962407,
#  'preferred': 0.0015037593984962407,
#  'minimum': 0.0015037593984962407,
#  'description': 0.0015037593984962407,
#  'length': 0.0015037593984962407,
#  'best': 0.0015037593984962407,
#  'model': 0.0030075187969924814,
#  'one': 0.0015037593984962407,
#  'minimizes': 0.0015037593984962407,
#  'information': 0.002255639097744361,
#  'needed': 0.0015037593984962407,
#  'encode': 0.0015037593984962407,
#  'preference': 0.0015037593984962407,
#  'simpler': 0.002255639097744361,
#  'avoidance': 0.0015037593984962407,
#  'closely': 0.0015037593984962407,
#  'related': 0.0015037593984962407,
#  'likely': 0.0015037593984962407,
#  'complex': 0.002255639097744361,
#  'solution': 0.002255639097744361,
#  'incorporates': 0.0015037593984962407,
#  'specific': 0.002255639097744361,
#  'thus': 0.0015037593984962407,
#  'mentioned': 0.0015037593984962407,
#  'argumentation': 0.0015037593984962407,
#  'taken': 0.002255639097744361,
#  'care': 0.0015037593984962407,
#  'too': 0.0015037593984962407,
#  'much': 0.0015037593984962407,
#  'emphasis': 0.0015037593984962407,
#  'minimizing': 0.0015037593984962407,
#  'discovery': 0.0015037593984962407,
#  'yet': 0.0015037593984962407,
#  'accurate': 0.0015037593984962407,
#  'there': 0.0015037593984962407,
#  'strong': 0.0015037593984962407,
#  'link': 0.0015037593984962407,
#  'control': 0.002255639097744361,
#  'code': 0.0030075187969924814,
#  'bloat': 0.0030075187969924814,
#  'exaggerated': 0.0015037593984962407,
#  'growth': 0.0015037593984962407,
#  'program': 0.0015037593984962407,
#  'course': 0.0015037593984962407,
#  'runs': 0.0015037593984962407,
#  'exactly': 0.0015037593984962407,
#  'phenomenon': 0.0015037593984962407,
#  'some': 0.0015037593984962407,
#  'kind': 0.0015037593984962407,
#  'generated': 0.002255639097744361,
#  'neutral': 0.0015037593984962407,
#  'pieces': 0.0015037593984962407,
#  'have': 0.0015037593984962407,
#  'no': 0.0015037593984962407,
#  'actual': 0.0015037593984962407,
#  'most': 0.0015037593984962407,
#  'mechanisms': 0.0015037593984962407,
#  'proposed': 0.002255639097744361,
#  'also': 0.0015037593984962407,
#  'minimize': 0.0015037593984962407,
#  'study': 0.0015037593984962407,
#  'viewed': 0.0015037593984962407,
#  'specifically': 0.0015037593984962407,
#  'techniques': 0.0030075187969924814,
#  'increase': 0.0015037593984962407,
#  'decrease': 0.0015037593984962407,
#  'use': 0.002255639097744361,
#  'generalize': 0.0015037593984962407,
#  'well': 0.0015037593984962407,
#  'lexicographic': 0.0015037593984962407,
#  'encoding': 0.0015037593984962407,
#  'vectors': 0.002255639097744361,
#  'terminals': 0.0015037593984962407,
#  'mathematical': 0.0015037593984962407,
#  'operations': 0.0015037593984962407,
#  'manipulate': 0.0015037593984962407,
#  'branches': 0.0015037593984962407,
#  'six': 0.0015037593984962407,
#  'different': 0.0015037593984962407,
#  'uci': 0.0015037593984962407,
#  'repository': 0.0015037593984962407,
#  'if': 0.0015037593984962407,
#  'context': 0.0015037593984962407,
#  'argue': 0.0015037593984962407,
#  'they': 0.0015037593984962407,
#  'extended': 0.0015037593984962407,
#  'frequent': 0.0015037593984962407,
#  'situations': 0.0015037593984962407,
#  'where': 0.0015037593984962407,
#  '[UNK]': 0.0007518796992481203}

# %% [markdown]
# ## Good Turing unigram smoothed counts

# %%
counter.view_normalised_counts(which_type = 'good turing')
# Out:
# {'abstract': 0.5658536585365853,
#  '[END]': 0.0,
#  'fitness': 0.5658536585365853,
#  'functions': 0.5658536585365853,
#  'based': 0.5658536585365853,
#  'on': 0.0,
#  'test': 5.625,
#  'cases': 1.2413793103448276,
#  'are': 9.0,
#  'very': 0.5658536585365853,
#  'common': 1.3333333333333333,
#  'in': 0.0,
#  'genetic': 0.5658536585365853,
#  'programming': 0.5658536585365853,
#  'gp': 5.5,
#  'this': 34.0,
#  'process': 1.2413793103448276,
#  'can': 5.5,
#  'be': 0.0,
#  'assimilated': 1.2413793103448276,
#  'to': 0.0,
#  'a': 0.0,
#  'learning': 0.0,
#  'task': 0.5658536585365853,
#  'with': 12.0,
#  'the': 0.0,
#  'inference': 0.5658536585365853,
#  'of': 0.0,
#  'models': 1.3333333333333333,
#  'from': 3.3333333333333335,
#  'limited': 1.2413793103448276,
#  'number': 1.2413793103448276,
#  'samples': 0.5658536585365853,
#  'paper': 5.625,
#  'is': 0.0,
#  'an': 3.3333333333333335,
#  'investigation': 0.5658536585365853,
#  'two': 5.625,
#  'methods': 1.2413793103448276,
#  'improve': 0.5658536585365853,
#  'generalization': 3.3333333333333335,
#  'gp-based': 5.625,
#  'selection': 0.5658536585365853,
#  'best-of-run': 1.3333333333333333,
#  'individuals': 1.3333333333333333,
#  'using': 3.3333333333333335,
#  'three': 0.5658536585365853,
#  'data': 0.0,
#  'sets': 12.0,
#  'methodology': 3.3333333333333335,
#  'and': 22.0,
#  'application': 1.3333333333333333,
#  'parsimony': 1.2413793103448276,
#  'pressure': 1.2413793103448276,
#  'order': 0.5658536585365853,
#  'reduce': 1.2413793103448276,
#  'complexity': 9.0,
#  'solutions': 13.333333333333334,
#  'results': 2.8,
#  'binary': 1.3333333333333333,
#  'classification': 1.3333333333333333,
#  'setup': 0.5658536585365853,
#  'show': 0.5658536585365853,
#  'that': 21.0,
#  'while': 0.5658536585365853,
#  'accuracy': 0.5658536585365853,
#  'preserved': 0.5658536585365853,
#  'less': 1.3333333333333333,
#  'variances': 0.5658536585365853,
#  'compared': 1.2413793103448276,
#  'baseline': 0.5658536585365853,
#  'mean': 0.5658536585365853,
#  'tree': 0.5658536585365853,
#  'size': 1.2413793103448276,
#  'obtained': 1.3333333333333333,
#  'tested': 5.625,
#  'significantly': 0.5658536585365853,
#  'reduced': 0.5658536585365853,
#  'introduction': 0.5658536585365853,
#  'particularly': 0.5658536585365853,
#  'suited': 0.5658536585365853,
#  'for': 2.8,
#  'problems': 3.3333333333333335,
#  'tasks': 0.5658536585365853,
#  'minimization': 1.2413793103448276,
#  'error': 0.5658536585365853,
#  'between': 1.3333333333333333,
#  'desired': 0.5658536585365853,
#  'outputs': 0.5658536585365853,
#  'training': 5.5,
#  'ml': 3.3333333333333335,
#  'terminology': 0.5658536585365853,
#  'indeed': 1.2413793103448276,
#  'classical': 0.5658536585365853,
#  'examples': 0.5658536585365853,
#  'symbolic': 0.5658536585365853,
#  'regression': 1.2413793103448276,
#  'boolean': 0.5658536585365853,
#  'multiplexer': 0.5658536585365853,
#  'artificial': 0.5658536585365853,
#  'ant': 0.5658536585365853,
#  'citation': 13.333333333333334,
#  'only': 1.2413793103448276,
#  'simple': 1.2413793103448276,
#  'instances': 0.5658536585365853,
#  'well-known': 0.5658536585365853,
#  'i': 0.5658536585365853,
#  'e': 0.5658536585365853,
#  'respectively': 0.5658536585365853,
#  'reinforcement': 0.5658536585365853,
#  'early': 0.5658536585365853,
#  'years': 0.5658536585365853,
#  'these': 3.3333333333333335,
#  'were': 1.2413793103448276,
#  'tackled': 0.5658536585365853,
#  'single': 0.5658536585365853,
#  'set': 0.0,
#  'reporting': 1.3333333333333333,
#  'same': 1.3333333333333333,
#  'was': 1.3333333333333333,
#  'used': 5.5,
#  'evaluate': 0.5658536585365853,
#  'fitnesses': 0.5658536585365853,
#  'during': 5.625,
#  'evolution': 1.2413793103448276,
#  'justifiable': 0.5658536585365853,
#  'by': 2.8,
#  'fact': 0.5658536585365853,
#  'toy': 0.5658536585365853,
#  'illustrate': 0.5658536585365853,
#  'potential': 0.5658536585365853,
#  'community': 1.2413793103448276,
#  'it': 2.8,
#  'recognized': 0.5658536585365853,
#  'such': 1.2413793103448276,
#  'flawed': 1.2413793103448276,
#  'given': 1.2413793103448276,
#  'algorithm': 13.333333333333334,
#  'overfit': 1.2413793103448276,
#  'perform': 0.5658536585365853,
#  'poorly': 0.5658536585365853,
#  'unseen': 1.2413793103448276,
#  'domain': 0.5658536585365853,
#  'hence': 0.5658536585365853,
#  'important': 1.2413793103448276,
#  'report': 1.2413793103448276,
#  'not': 1.3333333333333333,
#  'stage': 0.5658536585365853,
#  'what': 0.5658536585365853,
#  'we': 1.3333333333333333,
#  'call': 0.5658536585365853,
#  'performance': 1.2413793103448276,
#  'which': 3.3333333333333335,
#  'good': 0.5658536585365853,
#  'indicator': 0.5658536585365853,
#  's': 1.2413793103448276,
#  'or': 1.2413793103448276,
#  'robustness': 0.5658536585365853,
#  'capability': 1.2413793103448276,
#  'even': 1.3333333333333333,
#  'though': 1.2413793103448276,
#  'has': 1.3333333333333333,
#  'been': 1.2413793103448276,
#  'widely': 0.5658536585365853,
#  'accepted': 0.5658536585365853,
#  'applied': 1.2413793103448276,
#  'pr': 1.2413793103448276,
#  'communities': 1.2413793103448276,
#  'long': 0.5658536585365853,
#  'time': 0.5658536585365853,
#  'ec': 0.5658536585365853,
#  'still': 0.5658536585365853,
#  'lags': 0.5658536585365853,
#  'behind': 1.2413793103448276,
#  'publishing': 0.5658536585365853,
#  'papers': 0.5658536585365853,
#  'phase': 0.5658536585365853,
#  'methodological': 0.5658536585365853,
#  'problem': 0.5658536585365853,
#  'already': 0.5658536585365853,
#  'spotted': 0.5658536585365853,
#  'see': 0.5658536585365853,
#  'should': 1.2413793103448276,
#  'future': 0.5658536585365853,
#  'prevents': 0.5658536585365853,
#  'algorithms': 1.2413793103448276,
#  'but': 1.3333333333333333,
#  'does': 0.5658536585365853,
#  'prevent': 1.2413793103448276,
#  'itself': 0.5658536585365853,
#  'overfitting': 5.625,
#  'approach': 1.3333333333333333,
#  'add': 0.5658536585365853,
#  'third': 1.2413793103448276,
#  'validation': 5.625,
#  'helps': 0.5658536585365853,
#  'measure': 0.5658536585365853,
#  'its': 0.5658536585365853,
#  'useful': 0.5658536585365853,
#  'interrupt': 0.5658536585365853,
#  'when': 0.5658536585365853,
#  'occurs': 0.5658536585365853,
#  'select': 1.3333333333333333,
#  'configuration': 0.5658536585365853,
#  'machine': 0.5658536585365853,
#  'maximizes': 0.5658536585365853,
#  'performances': 0.5658536585365853,
#  'commonly': 0.5658536585365853,
#  'train': 0.5658536585365853,
#  'classifiers': 0.5658536585365853,
#  'as': 9.0,
#  'back-propagation': 0.5658536585365853,
#  'neural': 0.5658536585365853,
#  'networks': 0.5658536585365853,
#  'easily': 0.5658536585365853,
#  'ec-based': 0.5658536585365853,
#  'drawback': 0.5658536585365853,
#  'removes': 0.5658536585365853,
#  'significant': 0.5658536585365853,
#  'amount': 1.2413793103448276,
#  'harmful': 0.5658536585365853,
#  'richer': 0.5658536585365853,
#  'more': 2.8,
#  'representative': 0.5658536585365853,
#  'real': 0.5658536585365853,
#  'distribution': 0.5658536585365853,
#  'expected': 0.5658536585365853,
#  'converge': 0.5658536585365853,
#  'toward': 0.5658536585365853,
#  'robust': 0.5658536585365853,
#  'light': 0.5658536585365853,
#  'considerations': 0.5658536585365853,
#  'objective': 0.5658536585365853,
#  'investigate': 1.2413793103448276,
#  'effect': 1.2413793103448276,
#  'another': 1.2413793103448276,
#  'concern': 0.5658536585365853,
#  'develop': 0.5658536585365853,
#  'generate': 0.5658536585365853,
#  'argument': 1.2413793103448276,
#  'occam': 0.5658536585365853,
#  'razor': 0.5658536585365853,
#  'principle': 1.2413793103448276,
#  'states': 1.2413793103448276,
#  'comparable': 0.5658536585365853,
#  'quality': 0.5658536585365853,
#  'simplest': 0.5658536585365853,
#  'must': 0.5658536585365853,
#  'preferred': 0.5658536585365853,
#  'minimum': 0.5658536585365853,
#  'description': 0.5658536585365853,
#  'length': 0.5658536585365853,
#  'best': 0.5658536585365853,
#  'model': 1.3333333333333333,
#  'one': 0.5658536585365853,
#  'minimizes': 0.5658536585365853,
#  'information': 1.2413793103448276,
#  'needed': 0.5658536585365853,
#  'encode': 0.5658536585365853,
#  'preference': 0.5658536585365853,
#  'simpler': 1.2413793103448276,
#  'avoidance': 0.5658536585365853,
#  'closely': 0.5658536585365853,
#  'related': 0.5658536585365853,
#  'likely': 0.5658536585365853,
#  'complex': 1.2413793103448276,
#  'solution': 1.2413793103448276,
#  'incorporates': 0.5658536585365853,
#  'specific': 1.2413793103448276,
#  'thus': 0.5658536585365853,
#  'mentioned': 0.5658536585365853,
#  'argumentation': 0.5658536585365853,
#  'taken': 1.2413793103448276,
#  'care': 0.5658536585365853,
#  'too': 0.5658536585365853,
#  'much': 0.5658536585365853,
#  'emphasis': 0.5658536585365853,
#  'minimizing': 0.5658536585365853,
#  'discovery': 0.5658536585365853,
#  'yet': 0.5658536585365853,
#  'accurate': 0.5658536585365853,
#  'there': 0.5658536585365853,
#  'strong': 0.5658536585365853,
#  'link': 0.5658536585365853,
#  'control': 1.2413793103448276,
#  'code': 1.3333333333333333,
#  'bloat': 1.3333333333333333,
#  'exaggerated': 0.5658536585365853,
#  'growth': 0.5658536585365853,
#  'program': 0.5658536585365853,
#  'course': 0.5658536585365853,
#  'runs': 0.5658536585365853,
#  'exactly': 0.5658536585365853,
#  'phenomenon': 0.5658536585365853,
#  'some': 0.5658536585365853,
#  'kind': 0.5658536585365853,
#  'generated': 1.2413793103448276,
#  'neutral': 0.5658536585365853,
#  'pieces': 0.5658536585365853,
#  'have': 0.5658536585365853,
#  'no': 0.5658536585365853,
#  'actual': 0.5658536585365853,
#  'most': 0.5658536585365853,
#  'mechanisms': 0.5658536585365853,
#  'proposed': 1.2413793103448276,
#  'also': 0.5658536585365853,
#  'minimize': 0.5658536585365853,
#  'study': 0.5658536585365853,
#  'viewed': 0.5658536585365853,
#  'specifically': 0.5658536585365853,
#  'techniques': 1.3333333333333333,
#  'increase': 0.5658536585365853,
#  'decrease': 0.5658536585365853,
#  'use': 1.2413793103448276,
#  'generalize': 0.5658536585365853,
#  'well': 0.5658536585365853,
#  'lexicographic': 0.5658536585365853,
#  'encoding': 0.5658536585365853,
#  'vectors': 1.2413793103448276,
#  'terminals': 0.5658536585365853,
#  'mathematical': 0.5658536585365853,
#  'operations': 0.5658536585365853,
#  'manipulate': 0.5658536585365853,
#  'branches': 0.5658536585365853,
#  'six': 0.5658536585365853,
#  'different': 0.5658536585365853,
#  'uci': 0.5658536585365853,
#  'repository': 0.5658536585365853,
#  'if': 0.5658536585365853,
#  'context': 0.5658536585365853,
#  'argue': 0.5658536585365853,
#  'they': 0.5658536585365853,
#  'extended': 0.5658536585365853,
#  'frequent': 0.5658536585365853,
#  'situations': 0.5658536585365853,
#  'where': 0.5658536585365853}

# %%
model_good_turing = UnigramModel(counter)
model_good_turing.train(which_type = 'good turing')
model_good_turing.probs
# Out:
# {'abstract': 0.11681772406847936,
#  '[END]': 0.0,
#  'fitness': 0.11681772406847936,
#  'functions': 0.11681772406847936,
#  'based': 0.11681772406847936,
#  'on': 0.0,
#  'test': 0.045317220543806644,
#  'cases': 0.07250755287009064,
#  'are': 0.027190332326283987,
#  'very': 0.11681772406847936,
#  'common': 0.032225579053373615,
#  'in': 0.0,
#  'genetic': 0.11681772406847936,
#  'programming': 0.11681772406847936,
#  'gp': 0.022155085599194362,
#  'this': 0.03423967774420947,
#  'process': 0.07250755287009064,
#  'can': 0.022155085599194362,
#  'be': 0.0,
#  'assimilated': 0.07250755287009064,
#  'to': 0.0,
#  'a': 0.0,
#  'learning': 0.0,
#  'task': 0.11681772406847936,
#  'with': 0.02416918429003021,
#  'the': 0.0,
#  'inference': 0.11681772406847936,
#  'of': 0.0,
#  'models': 0.032225579053373615,
#  'from': 0.030211480362537766,
#  'limited': 0.07250755287009064,
#  'number': 0.07250755287009064,
#  'samples': 0.11681772406847936,
#  'paper': 0.045317220543806644,
#  'is': 0.0,
#  'an': 0.030211480362537766,
#  'investigation': 0.11681772406847936,
#  'two': 0.045317220543806644,
#  'methods': 0.07250755287009064,
#  'improve': 0.11681772406847936,
#  'generalization': 0.030211480362537766,
#  'gp-based': 0.045317220543806644,
#  'selection': 0.11681772406847936,
#  'best-of-run': 0.032225579053373615,
#  'individuals': 0.032225579053373615,
#  'using': 0.030211480362537766,
#  'three': 0.11681772406847936,
#  'data': 0.0,
#  'sets': 0.02416918429003021,
#  'methodology': 0.030211480362537766,
#  'and': 0.022155085599194362,
#  'application': 0.032225579053373615,
#  'parsimony': 0.07250755287009064,
#  'pressure': 0.07250755287009064,
#  'order': 0.11681772406847936,
#  'reduce': 0.07250755287009064,
#  'complexity': 0.027190332326283987,
#  'solutions': 0.04028197381671702,
#  'results': 0.014098690835850957,
#  'binary': 0.032225579053373615,
#  'classification': 0.032225579053373615,
#  'setup': 0.11681772406847936,
#  'show': 0.11681772406847936,
#  'that': 0.021148036253776436,
#  'while': 0.11681772406847936,
#  'accuracy': 0.11681772406847936,
#  'preserved': 0.11681772406847936,
#  'less': 0.032225579053373615,
#  'variances': 0.11681772406847936,
#  'compared': 0.07250755287009064,
#  'baseline': 0.11681772406847936,
#  'mean': 0.11681772406847936,
#  'tree': 0.11681772406847936,
#  'size': 0.07250755287009064,
#  'obtained': 0.032225579053373615,
#  'tested': 0.045317220543806644,
#  'significantly': 0.11681772406847936,
#  'reduced': 0.11681772406847936,
#  'introduction': 0.11681772406847936,
#  'particularly': 0.11681772406847936,
#  'suited': 0.11681772406847936,
#  'for': 0.014098690835850957,
#  'problems': 0.030211480362537766,
#  'tasks': 0.11681772406847936,
#  'minimization': 0.07250755287009064,
#  'error': 0.11681772406847936,
#  'between': 0.032225579053373615,
#  'desired': 0.11681772406847936,
#  'outputs': 0.11681772406847936,
#  'training': 0.022155085599194362,
#  'ml': 0.030211480362537766,
#  'terminology': 0.11681772406847936,
#  'indeed': 0.07250755287009064,
#  'classical': 0.11681772406847936,
#  'examples': 0.11681772406847936,
#  'symbolic': 0.11681772406847936,
#  'regression': 0.07250755287009064,
#  'boolean': 0.11681772406847936,
#  'multiplexer': 0.11681772406847936,
#  'artificial': 0.11681772406847936,
#  'ant': 0.11681772406847936,
#  'citation': 0.04028197381671702,
#  'only': 0.07250755287009064,
#  'simple': 0.07250755287009064,
#  'instances': 0.11681772406847936,
#  'well-known': 0.11681772406847936,
#  'i': 0.11681772406847936,
#  'e': 0.11681772406847936,
#  'respectively': 0.11681772406847936,
#  'reinforcement': 0.11681772406847936,
#  'early': 0.11681772406847936,
#  'years': 0.11681772406847936,
#  'these': 0.030211480362537766,
#  'were': 0.07250755287009064,
#  'tackled': 0.11681772406847936,
#  'single': 0.11681772406847936,
#  'set': 0.0,
#  'reporting': 0.032225579053373615,
#  'same': 0.032225579053373615,
#  'was': 0.032225579053373615,
#  'used': 0.022155085599194362,
#  'evaluate': 0.11681772406847936,
#  'fitnesses': 0.11681772406847936,
#  'during': 0.045317220543806644,
#  'evolution': 0.07250755287009064,
#  'justifiable': 0.11681772406847936,
#  'by': 0.014098690835850957,
#  'fact': 0.11681772406847936,
#  'toy': 0.11681772406847936,
#  'illustrate': 0.11681772406847936,
#  'potential': 0.11681772406847936,
#  'community': 0.07250755287009064,
#  'it': 0.014098690835850957,
#  'recognized': 0.11681772406847936,
#  'such': 0.07250755287009064,
#  'flawed': 0.07250755287009064,
#  'given': 0.07250755287009064,
#  'algorithm': 0.04028197381671702,
#  'overfit': 0.07250755287009064,
#  'perform': 0.11681772406847936,
#  'poorly': 0.11681772406847936,
#  'unseen': 0.07250755287009064,
#  'domain': 0.11681772406847936,
#  'hence': 0.11681772406847936,
#  'important': 0.07250755287009064,
#  'report': 0.07250755287009064,
#  'not': 0.032225579053373615,
#  'stage': 0.11681772406847936,
#  'what': 0.11681772406847936,
#  'we': 0.032225579053373615,
#  'call': 0.11681772406847936,
#  'performance': 0.07250755287009064,
#  'which': 0.030211480362537766,
#  'good': 0.11681772406847936,
#  'indicator': 0.11681772406847936,
#  's': 0.07250755287009064,
#  'or': 0.07250755287009064,
#  'robustness': 0.11681772406847936,
#  'capability': 0.07250755287009064,
#  'even': 0.032225579053373615,
#  'though': 0.07250755287009064,
#  'has': 0.032225579053373615,
#  'been': 0.07250755287009064,
#  'widely': 0.11681772406847936,
#  'accepted': 0.11681772406847936,
#  'applied': 0.07250755287009064,
#  'pr': 0.07250755287009064,
#  'communities': 0.07250755287009064,
#  'long': 0.11681772406847936,
#  'time': 0.11681772406847936,
#  'ec': 0.11681772406847936,
#  'still': 0.11681772406847936,
#  'lags': 0.11681772406847936,
#  'behind': 0.07250755287009064,
#  'publishing': 0.11681772406847936,
#  'papers': 0.11681772406847936,
#  'phase': 0.11681772406847936,
#  'methodological': 0.11681772406847936,
#  'problem': 0.11681772406847936,
#  'already': 0.11681772406847936,
#  'spotted': 0.11681772406847936,
#  'see': 0.11681772406847936,
#  'should': 0.07250755287009064,
#  'future': 0.11681772406847936,
#  'prevents': 0.11681772406847936,
#  'algorithms': 0.07250755287009064,
#  'but': 0.032225579053373615,
#  'does': 0.11681772406847936,
#  'prevent': 0.07250755287009064,
#  'itself': 0.11681772406847936,
#  'overfitting': 0.045317220543806644,
#  'approach': 0.032225579053373615,
#  'add': 0.11681772406847936,
#  'third': 0.07250755287009064,
#  'validation': 0.045317220543806644,
#  'helps': 0.11681772406847936,
#  'measure': 0.11681772406847936,
#  'its': 0.11681772406847936,
#  'useful': 0.11681772406847936,
#  'interrupt': 0.11681772406847936,
#  'when': 0.11681772406847936,
#  'occurs': 0.11681772406847936,
#  'select': 0.032225579053373615,
#  'configuration': 0.11681772406847936,
#  'machine': 0.11681772406847936,
#  'maximizes': 0.11681772406847936,
#  'performances': 0.11681772406847936,
#  'commonly': 0.11681772406847936,
#  'train': 0.11681772406847936,
#  'classifiers': 0.11681772406847936,
#  'as': 0.027190332326283987,
#  'back-propagation': 0.11681772406847936,
#  'neural': 0.11681772406847936,
#  'networks': 0.11681772406847936,
#  'easily': 0.11681772406847936,
#  'ec-based': 0.11681772406847936,
#  'drawback': 0.11681772406847936,
#  'removes': 0.11681772406847936,
#  'significant': 0.11681772406847936,
#  'amount': 0.07250755287009064,
#  'harmful': 0.11681772406847936,
#  'richer': 0.11681772406847936,
#  'more': 0.014098690835850957,
#  'representative': 0.11681772406847936,
#  'real': 0.11681772406847936,
#  'distribution': 0.11681772406847936,
#  'expected': 0.11681772406847936,
#  'converge': 0.11681772406847936,
#  'toward': 0.11681772406847936,
#  'robust': 0.11681772406847936,
#  'light': 0.11681772406847936,
#  'considerations': 0.11681772406847936,
#  'objective': 0.11681772406847936,
#  'investigate': 0.07250755287009064,
#  'effect': 0.07250755287009064,
#  'another': 0.07250755287009064,
#  'concern': 0.11681772406847936,
#  'develop': 0.11681772406847936,
#  'generate': 0.11681772406847936,
#  'argument': 0.07250755287009064,
#  'occam': 0.11681772406847936,
#  'razor': 0.11681772406847936,
#  'principle': 0.07250755287009064,
#  'states': 0.07250755287009064,
#  'comparable': 0.11681772406847936,
#  'quality': 0.11681772406847936,
#  'simplest': 0.11681772406847936,
#  'must': 0.11681772406847936,
#  'preferred': 0.11681772406847936,
#  'minimum': 0.11681772406847936,
#  'description': 0.11681772406847936,
#  'length': 0.11681772406847936,
#  'best': 0.11681772406847936,
#  'model': 0.032225579053373615,
#  'one': 0.11681772406847936,
#  'minimizes': 0.11681772406847936,
#  'information': 0.07250755287009064,
#  'needed': 0.11681772406847936,
#  'encode': 0.11681772406847936,
#  'preference': 0.11681772406847936,
#  'simpler': 0.07250755287009064,
#  'avoidance': 0.11681772406847936,
#  'closely': 0.11681772406847936,
#  'related': 0.11681772406847936,
#  'likely': 0.11681772406847936,
#  'complex': 0.07250755287009064,
#  'solution': 0.07250755287009064,
#  'incorporates': 0.11681772406847936,
#  'specific': 0.07250755287009064,
#  'thus': 0.11681772406847936,
#  'mentioned': 0.11681772406847936,
#  'argumentation': 0.11681772406847936,
#  'taken': 0.07250755287009064,
#  'care': 0.11681772406847936,
#  'too': 0.11681772406847936,
#  'much': 0.11681772406847936,
#  'emphasis': 0.11681772406847936,
#  'minimizing': 0.11681772406847936,
#  'discovery': 0.11681772406847936,
#  'yet': 0.11681772406847936,
#  'accurate': 0.11681772406847936,
#  'there': 0.11681772406847936,
#  'strong': 0.11681772406847936,
#  'link': 0.11681772406847936,
#  'control': 0.07250755287009064,
#  'code': 0.032225579053373615,
#  'bloat': 0.032225579053373615,
#  'exaggerated': 0.11681772406847936,
#  'growth': 0.11681772406847936,
#  'program': 0.11681772406847936,
#  'course': 0.11681772406847936,
#  'runs': 0.11681772406847936,
#  'exactly': 0.11681772406847936,
#  'phenomenon': 0.11681772406847936,
#  'some': 0.11681772406847936,
#  'kind': 0.11681772406847936,
#  'generated': 0.07250755287009064,
#  'neutral': 0.11681772406847936,
#  'pieces': 0.11681772406847936,
#  'have': 0.11681772406847936,
#  'no': 0.11681772406847936,
#  'actual': 0.11681772406847936,
#  'most': 0.11681772406847936,
#  'mechanisms': 0.11681772406847936,
#  'proposed': 0.07250755287009064,
#  'also': 0.11681772406847936,
#  'minimize': 0.11681772406847936,
#  'study': 0.11681772406847936,
#  'viewed': 0.11681772406847936,
#  'specifically': 0.11681772406847936,
#  'techniques': 0.032225579053373615,
#  'increase': 0.11681772406847936,
#  'decrease': 0.11681772406847936,
#  'use': 0.07250755287009064,
#  'generalize': 0.11681772406847936,
#  'well': 0.11681772406847936,
#  'lexicographic': 0.11681772406847936,
#  'encoding': 0.11681772406847936,
#  'vectors': 0.07250755287009064,
#  'terminals': 0.11681772406847936,
#  'mathematical': 0.11681772406847936,
#  'operations': 0.11681772406847936,
#  'manipulate': 0.11681772406847936,
#  'branches': 0.11681772406847936,
#  'six': 0.11681772406847936,
#  'different': 0.11681772406847936,
#  'uci': 0.11681772406847936,
#  'repository': 0.11681772406847936,
#  'if': 0.11681772406847936,
#  'context': 0.11681772406847936,
#  'argue': 0.11681772406847936,
#  'they': 0.11681772406847936,
#  'extended': 0.11681772406847936,
#  'frequent': 0.11681772406847936,
#  'situations': 0.11681772406847936,
#  'where': 0.11681772406847936,
#  '[UNK]': 0.20644511581067473}

# %%
test_data = open_and_clean_file_data('./test_raw.txt')

# %%
test_data
# Out:
# ['the goal of this project is to translate the wonderful resource [END]']

# %%
evaluationCounter = UnigramCounter(test_data)
print(evaluationCounter.token_count)
print(evaluationCounter.counts)
# Out:
# 12
# defaultdict(<class 'int'>, {'the': 2, 'goal': 1, 'of': 1, 'this': 1, 'project': 1, 'is': 1, 'to': 1, 'translate': 1, 'wonderful': 1, 'resource': 1, '[END]': 1})

# %%
model_no_smoothing.evaluate(evaluationCounter)
# Out:
# the -> 0.08459214501510574 probability
# [UNK] -> 0.0 probability
# of -> 0.04028197381671702 probability
# this -> 0.016112789526686808 probability
# [UNK] -> 0.0 probability
# is -> 0.02416918429003021 probability
# to -> 0.028197381671701913 probability
# [UNK] -> 0.0 probability
# [UNK] -> 0.0 probability
# [UNK] -> 0.0 probability
# [END] -> 0.035246727089627394 probability
# 0.0

# %%
model_add_one.evaluate(evaluationCounter)
# Out:
# the -> 0.06390977443609022 probability
# [UNK] -> 0.0007518796992481203 probability
# of -> 0.030827067669172932 probability
# this -> 0.012781954887218045 probability
# [UNK] -> 0.0007518796992481203 probability
# is -> 0.018796992481203006 probability
# to -> 0.02180451127819549 probability
# [UNK] -> 0.0007518796992481203 probability
# [UNK] -> 0.0007518796992481203 probability
# [UNK] -> 0.0007518796992481203 probability
# [END] -> 0.02706766917293233 probability
# 6.713116136417485e-26

# %%
model_good_turing.evaluate(evaluationCounter)
# Out:
# the -> 0.0 probability
# [UNK] -> 0.20644511581067473 probability
# of -> 0.0 probability
# this -> 0.03423967774420947 probability
# [UNK] -> 0.20644511581067473 probability
# is -> 0.0 probability
# to -> 0.0 probability
# [UNK] -> 0.20644511581067473 probability
# [UNK] -> 0.20644511581067473 probability
# [UNK] -> 0.20644511581067473 probability
# [END] -> 0.0 probability
# 0.0
